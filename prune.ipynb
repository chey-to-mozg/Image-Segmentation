# %%
import tensorflow.keras as keras
import segmentation_models as sm
sm.set_framework('tf.keras')
import random
import re
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
import glob
import cv2
import numpy as np
import matplotlib.pyplot as plt
import shutil
from pathlib import Path
import tensorflow as tf
from tensorflow.keras import datasets, utils, callbacks, optimizers, losses
from keras.preprocessing.image import ImageDataGenerator

import ridurre
from example.cifar_10_resnet import resnet
from ridurre import model_complexity

N_CLASSES = 1
LR = 0.0001


print('[LOAD DATA FROM DISK]')


def split_set(set_, k_train, k_val, k_test):
    quantity = len(set_)
    random.shuffle(set_)
    train_quantity = round(quantity*k_train)
    val_quatity= round(quantity*k_val)

    train = set_[0:train_quantity]
    val = set_[train_quantity:train_quantity+val_quatity]
    test= set_[-1:train_quantity+val_quatity-1:-1]

    return train, val, test


def sync_test_redundant_images(path_to_images, images, annotations):
    images_sync = []
    for annot_image in annotations:
        annot_image = re.split('[./\\\]', annot_image)[-2]
        images_sync.append(os.path.join(path_to_images,'train',annot_image + '.tif'))
    return images_sync, annotations




def load_train_annot_dataset(path_to_images, k_train=0.85, k_val=0.1, k_test=0.05):
    train_paths = glob.glob(os.path.join(path_to_images, 'train', '*'))
    annot_paths = glob.glob(os.path.join(path_to_images, 'annot', '*'))

#     train_paths =  os.listdir(os.path.join(path_to_images, 'train'))
#     annot_paths = os.listdir(os.path.join(path_to_images, 'annot'))

    train_annotations, val_annotations, test_annotations = split_set(annot_paths, k_train, k_val, k_test)
    train_images, val_images, test_images = split_set(train_paths, k_train, k_val, k_test)

    train_images, train_annotations = sync_test_redundant_images(path_to_images, train_images, train_annotations)
    test_images, test_annotations = sync_test_redundant_images(path_to_images,test_images, test_annotations)
    val_images, val_annotations = sync_test_redundant_images(path_to_images,val_images, val_annotations)

    assert len(annot_paths) == len(train_annotations) + len(val_annotations) + len(test_annotations)




    return train_images, train_annotations, val_images, val_annotations, test_images, test_annotations
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From d:\study\skolkovo_immersion\prune_net\ridurre-network-filter-pruning-keras\prune\lib\site-packages\swiss_army_tensorboard\tfboard_loggers\tfboard_loggers.py:47: The name tf.HistogramProto is deprecated. Please use tf.compat.v1.HistogramProto instead.
# Segmentation Models: using `keras` framework.
# WARNING:tensorflow:From d:\study\skolkovo_immersion\prune_net\ridurre-network-filter-pruning-keras\prune\lib\site-packages\swiss_army_tensorboard\tfboard_loggers\tfboard_loggers.py:47: The name tf.HistogramProto is deprecated. Please use tf.compat.v1.HistogramProto instead.
#
# [LOAD DATA FROM DISK]

# %%
DATA_DIR = 'D:\Study\Skolkovo_Immersion\matching'

# %%
train_images, train_annotations, val_images, val_annotations, \
test_images, test_annotations = load_train_annot_dataset(DATA_DIR)

print('[DATA LOADED FROM DISK]')

# helper function for data visualization
def visualize(**images):
    """PLot images in one row."""
    n = len(images)
    plt.figure(figsize=(30, 30))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        plt.imshow(image)
    plt.show()

# helper function for data visualization
def denormalize(x):
    """Scale image to range 0..1 for correct plot"""
    x_max = np.percentile(x, 98)
    x_min = np.percentile(x, 2)
    x = (x - x_min) / (x_max - x_min)
    x = x.clip(0, 1)
    return x


# classes for data loading and preprocessing
class Dataset:
    """CamVid Dataset. Read images, apply augmentation and preprocessing transformations.

    Args:
        images_dir (str): path to images folder
        masks_dir (str): path to segmentation masks folder
        class_values (list): values of classes to extract from segmentation mask
        augmentation (albumentations.Compose): data transfromation pipeline
            (e.g. flip, scale, etc.)
        preprocessing (albumentations.Compose): data preprocessing
            (e.g. noralization, shape manipulation, etc.)

    """

    CLASSES = ['leaf']

    def __init__(
            self,
            images,
            masks,
            classes=None,
            augmentation=None,
            preprocessing=None,
    ):

        self.masks_fps = masks
        self.images_fps = images
        self.ids = len(self.masks_fps) #if len(self.masks_fps) == len(self.images_fps)
        # convert str names to class values on masks4
        self.class_values = [self.CLASSES.index(cls.lower()) for cls in classes]

        self.augmentation = augmentation
        self.preprocessing = preprocessing

    def __getitem__(self, i):

        # read data
        image = cv2.imread(self.images_fps[i], -1)
        #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        mask = cv2.imread(self.masks_fps[i], 0)
        # extract certain classes from mask (e.g. cars)
        masks = [(mask == v) for v in self.class_values]
        mask = np.stack(masks, axis=-1).astype('float')

        # add background if mask is not binary
        if mask.shape[-1] != 1:
            background = 1 - mask.sum(axis=-1, keepdims=True)
            mask = np.concatenate((mask, background), axis=-1)

        # apply augmentations
        if self.augmentation:

            sample = self.augmentation(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']

        # apply preprocessing
        if self.preprocessing:
            sample = self.preprocessing(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']

        return image, mask

    def __len__(self):
        return self.ids


class Dataloder(keras.utils.Sequence):
    """Load data from dataset and form batches

    Args:
        dataset: instance of Dataset class for image loading and preprocessing.
        batch_size: Integet number of images in batch.
        shuffle: Boolean, if `True` shuffle image indexes each epoch.
    """

    def __init__(self, dataset, batch_size=1, shuffle=False):
        self.dataset = dataset
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indexes = np.arange(len(dataset))

        self.on_epoch_end()

    def __getitem__(self, i):

        # collect batch data
        start = i * self.batch_size
        stop = (i + 1) * self.batch_size
        X, Y = [], []
        for j in range(start, stop):
            data = self.dataset[j]
            X.append(data[0])
            Y.append(data[1])
        # transpose list of lists
        X = np.array(X)
        Y = np.array(Y)
        ######
        if len(X.shape) < 4:
            X = np.expand_dims(X, axis=3)
        return X, Y

    def __len__(self):
        """Denotes the number of batches per epoch"""
        return len(self.indexes) // self.batch_size

    def on_epoch_end(self):
        """Callback function to shuffle indexes each epoch"""
        if self.shuffle:
            self.indexes = np.random.permutation(self.indexes)

import albumentations as A

def round_clip_0_1(x, **kwargs):
    return x.round().clip(0, 1)

# define heavy augmentations
def get_training_augmentation():
    train_transform = [

        A.HorizontalFlip(p=0.5),
#         A.VerticalFlip(p=0.1),
        A.ShiftScaleRotate(scale_limit=(-0.2,0.2), rotate_limit=(-15,15), shift_limit=(-0.01,0.01), p=0.7, border_mode=cv2.BORDER_CONSTANT, mask_value=1),
        A.RandomCrop(height=640, width=960, always_apply=True),
        # A.RandomCrop(height=400, width=560, p=0.3),
        A.PadIfNeeded(min_height=640, min_width=960, always_apply=True, border_mode=cv2.BORDER_CONSTANT, mask_value=1),

#         A.IAAAdditiveGaussianNoise(p=0.2),
        A.IAAPerspective(p=0.5),

#         A.OneOf(
#             [
#                 A.CLAHE(p=1),
#                 A.RandomBrightness(p=0.2),
#                 A.RandomGamma(p=0.2),
#             ],
#             p=0.3,
#         ),

#         A.OneOf(
#             [
#                 A.IAASharpen(p=0.5),
#                 A.Blur(blur_limit=3, p=0.5),
#                 A.MotionBlur(blur_limit=3, p=0.5),
#             ],
#             p=0.3,
#         ),


        A.RandomContrast(limit=(-0.1, 0.1), p=0.2),
#                 A.HueSaturationValue(p=1),

        A.Lambda(mask=round_clip_0_1)
    ]
    return A.Compose(train_transform)


def get_validation_augmentation():
    """Add paddings to make image shape divisible by 32"""
    test_transform = [
        A.RandomCrop(height=640, width=960, always_apply=True)
    ]
    return A.Compose(test_transform)

def get_preprocessing(preprocessing_fn):
    """Construct preprocessing transform

    Args:
        preprocessing_fn (callbale): data normalization function
            (can be specific for each pretrained neural network)
    Return:
        transform: albumentations.Compose

    """

    _transform = [
        A.Lambda(image=preprocessing_fn),
    ]
    return A.Compose(_transform)

print('[CREATING DATASET]')

BACKBONE = 'efficientnetb3'
BATCH_SIZE = 1
CLASSES = ['leaf']
LR = 0.0001
EPOCHS = 30


train_dataset = Dataset(
    train_images,
    train_annotations,
    classes=CLASSES,
    augmentation=get_training_augmentation(),
#     preprocessing=get_preprocessing(preprocess_input),
)

# Dataset for validation images
valid_dataset = Dataset(
    val_images,
    val_annotations,
    classes=CLASSES,
    augmentation=get_validation_augmentation(),
#     preprocessing=get_preprocessing(preprocess_input),
)

train_dataloader = Dataloder(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
valid_dataloader = Dataloder(valid_dataset, batch_size=1, shuffle=False)

print('[DATASET CREATED]')
# Out:
# [DATA LOADED FROM DISK]
# [CREATING DATASET]
# [DATASET CREATED]

# %%
print('[LOAD MODEL FROM DISK]')


def load_model():
    # with open("path/to/json", 'r') as json_file:
    #     loaded_model_json = json_file.read()
    # loaded_model = model_from_json(loaded_model_json)
    # # load weights into new model
    # loaded_model.load_weights("path/to/h5")

    loaded_model = keras.models.load_model('pruned_model.h5', compile=False)

    return loaded_model

model = load_model()

#saving pretrained conv layer for 1->3 channels transform
pretrained_first_layer_weights = model.layers[1].get_weights()


model.summary()

print('[MODEL LOADED FROM DISK]')
# Out:
# [LOAD MODEL FROM DISK]
# WARNING:tensorflow:From d:\study\skolkovo_immersion\prune_net\ridurre-network-filter-pruning-keras\prune\lib\site-packages\tensorflow_core\python\ops\init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From d:\study\skolkovo_immersion\prune_net\ridurre-network-filter-pruning-keras\prune\lib\site-packages\tensorflow_core\python\ops\init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From d:\study\skolkovo_immersion\prune_net\ridurre-network-filter-pruning-keras\prune\lib\site-packages\tensorflow_core\python\ops\init_ops.py:97: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From d:\study\skolkovo_immersion\prune_net\ridurre-network-filter-pruning-keras\prune\lib\site-packages\tensorflow_core\python\util\deprecation.py:507: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with distribution=normal is deprecated and will be removed in a future version.
# Instructions for updating:
# `normal` is a deprecated alias for `truncated_normal`
# WARNING:tensorflow:From d:\study\skolkovo_immersion\prune_net\ridurre-network-filter-pruning-keras\prune\lib\site-packages\tensorflow_core\python\ops\init_ops.py:97: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From d:\study\skolkovo_immersion\prune_net\ridurre-network-filter-pruning-keras\prune\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:OMP_NUM_THREADS is no longer used by the default Keras config. To configure the number of threads, use tf.config.threading APIs.
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 640, 960, 1)]     0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 640, 960, 3)       6
# _________________________________________________________________
# model (Model)                (None, 640, 960, 1)       17867833
# =================================================================
# Total params: 17,867,839
# Trainable params: 17,778,559
# Non-trainable params: 89,280
# _________________________________________________________________
# [MODEL LOADED FROM DISK]
# WARNING:tensorflow:From d:\study\skolkovo_immersion\prune_net\ridurre-network-filter-pruning-keras\prune\lib\site-packages\tensorflow_core\python\ops\init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From d:\study\skolkovo_immersion\prune_net\ridurre-network-filter-pruning-keras\prune\lib\site-packages\tensorflow_core\python\ops\init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From d:\study\skolkovo_immersion\prune_net\ridurre-network-filter-pruning-keras\prune\lib\site-packages\tensorflow_core\python\ops\init_ops.py:97: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From d:\study\skolkovo_immersion\prune_net\ridurre-network-filter-pruning-keras\prune\lib\site-packages\tensorflow_core\python\util\deprecation.py:507: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with distribution=normal is deprecated and will be removed in a future version.
# Instructions for updating:
# `normal` is a deprecated alias for `truncated_normal`
# WARNING:tensorflow:From d:\study\skolkovo_immersion\prune_net\ridurre-network-filter-pruning-keras\prune\lib\site-packages\tensorflow_core\python\ops\init_ops.py:97: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From d:\study\skolkovo_immersion\prune_net\ridurre-network-filter-pruning-keras\prune\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:OMP_NUM_THREADS is no longer used by the default Keras config. To configure the number of threads, use tf.config.threading APIs.

# %%
def compile_model(model):

    inp_layer = keras.Input(shape=(None, None, 1))
    l1 = keras.layers.Conv2D(3, (1, 1))(inp_layer)

    out = model(l1)

    new_model = keras.Model(inp_layer, out)

    new_model.layers[1].set_weights(pretrained_first_layer_weights)

    optim = keras.optimizers.Adam(LR)

    # Segmentation models losses can be combined together by '+' and scaled by integer or float factor
    dice_loss = sm.losses.DiceLoss()
    focal_loss = sm.losses.BinaryFocalLoss() if N_CLASSES == 1 else sm.losses.CategoricalFocalLoss()
    total_loss = dice_loss + (1 * focal_loss)

    metrics = [sm.metrics.IOUScore(threshold=0.5), sm.metrics.FScore(threshold=0.5)]
    new_model.compile(optim, total_loss, metrics)
    return new_model

# %%
print('[PREPARING FOR TRAINING]')

TRAIN_LOGS_FOLDER_PATH = Path("./train_logs")

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(str(TRAIN_LOGS_FOLDER_PATH) + "/model_{epoch:02d}.h5",
                                                      save_best_only=False,
                                                      save_weights_only=False,
                                                      verbose=1
                                                      )

callbacks = [model_checkpoint_callback]

# Train the model
FIRST_TRAIN_EPOCHS = 1
BATCH_SIZE = 32
STEPS_PER_EPOCH = len(train_dataloader)
STEPS_VALID = len(valid_dataloader)
# Out:
# [PREPARING FOR TRAINING]

# %%
print('[COMPILING THE MODEL]')

optim = keras.optimizers.Adam(LR)

# Segmentation models losses can be combined together by '+' and scaled by integer or float factor
dice_loss = sm.losses.DiceLoss()
focal_loss = sm.losses.BinaryFocalLoss() if N_CLASSES == 1 else sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

metrics = [sm.metrics.IOUScore(threshold=0.5), sm.metrics.FScore(threshold=0.5)]
model.compile(optim, total_loss, metrics)
# Out:
# [COMPILING THE MODEL]

# %%
print('[TRAINING THE MODEL]')

model.fit_generator(train_dataloader,
                    steps_per_epoch=STEPS_PER_EPOCH,
                    epochs=FIRST_TRAIN_EPOCHS,
                    validation_data=valid_dataloader,
                    callbacks=callbacks,
                    validation_steps=STEPS_VALID
                    )

print('[MODEL PRETRAINED]')
# Out:
# [TRAINING THE MODEL]
# WARNING:tensorflow:From d:\study\skolkovo_immersion\prune_net\ridurre-network-filter-pruning-keras\prune\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1375: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
#  - ETA: 3:32 - loss: 0.0677 - iou_score: 0.9642 - f1-score: 0.9817
# Epoch 00001: saving model to train_logs/model_01.h5
# 260/260 [==============================] - 192s 738ms/step - loss: 0.0493 - iou_score: 0.9655 - f1-score: 0.9822 - val_loss: 0.0521 - val_iou_score: 0.9681 - val_f1-score: 0.9835
# [MODEL PRETRAINED]
# WARNING:tensorflow:From d:\study\skolkovo_immersion\prune_net\ridurre-network-filter-pruning-keras\prune\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1375: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
print('[SEGMENTATION]')

test_dataset = Dataset(
    test_images,
    test_annotations,
    classes=CLASSES,
    augmentation=get_validation_augmentation(),
    #preprocessing=get_preprocessing(preprocess_input),
)

test_dataloader = Dataloder(test_dataset, batch_size=1, shuffle=False)

ids = np.arange(len(test_dataset))


for i in ids:
    image, gt_mask = test_dataset[i]
    image = np.expand_dims(image, axis=0)
    image = np.expand_dims(image, axis=3)
    pr_mask = model.predict(image).round()
# img_kek = train_dataloader[0][0]
# pr_mask = model.predict(img_kek).round()
# plt.figure(figsize = (28,28))
# plt.imshow(img_kek[..., 0].squeeze(),cmap='gray')
# plt.show()
# print(np.max(img_kek))
#     cv2.imshow('mask', image[0][:][:])
#     cv2.waitKey(0)

    visualize(
        image=denormalize(image.squeeze()),
        gt_mask=gt_mask[..., 0].squeeze(),
        pr_mask=pr_mask[..., 0].squeeze(),
    )

# %%
print('[CRATING MODEL FOR PRUNING]')

BACKBONE = 'efficientnetb3'

n_classes = 1 if len(CLASSES) == 1 else (len(CLASSES) + 1)  # case for binary and multiclass segmentation
activation = 'sigmoid' if n_classes == 1 else 'softmax'

base_model = sm.Unet(BACKBONE, classes=n_classes, activation=activation, input_shape=(None, None, 3))

base_model.set_weights(model.layers[-1].get_weights())

model_for_pruning = base_model
# Out:
# [CRATING MODEL FOR PRUNING]

# %%
print('[START PRUNING]')

import tensorflow_model_optimization as tfmot

prune_low_magnitude = tfmot.sparsity.keras.prune_low_magnitude

# Compute end step to finish pruning after 2 epochs.
batch_size = 2
epochs = 2

end_step = np.ceil(len(train_images) / batch_size).astype(np.int32) * epochs

# Define model for pruning.
pruning_params = {
      'pruning_schedule': tfmot.sparsity.keras.PolynomialDecay(initial_sparsity=0.50,
                                                               final_sparsity=0.80,
                                                               begin_step=0,
                                                               end_step=end_step)
}

sub_model_for_prun = prune_low_magnitude(model_for_pruning, **pruning_params)

# `prune_low_magnitude` requires a recompile.


sub_model_for_prun.summary()
# Out:
# [START PRUNING]
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# prune_low_magnitude_stem_conv ( (None, None, None, 4 2162        input_1[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_stem_bn (Pr (None, None, None, 4 161         prune_low_magnitude_stem_conv[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_stem_activa (None, None, None, 4 1           prune_low_magnitude_stem_bn[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block1a_dwc (None, None, None, 4 361         prune_low_magnitude_stem_activati
# __________________________________________________________________________________________________
# prune_low_magnitude_block1a_bn  (None, None, None, 4 161         prune_low_magnitude_block1a_dwcon
# __________________________________________________________________________________________________
# prune_low_magnitude_block1a_act (None, None, None, 4 1           prune_low_magnitude_block1a_bn[0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block1a_se_ (None, 40)           1           prune_low_magnitude_block1a_activ
# __________________________________________________________________________________________________
# prune_low_magnitude_block1a_se_ (None, 1, 1, 40)     1           prune_low_magnitude_block1a_se_sq
# __________________________________________________________________________________________________
# prune_low_magnitude_block1a_se_ (None, 1, 1, 10)     812         prune_low_magnitude_block1a_se_re
# __________________________________________________________________________________________________
# prune_low_magnitude_block1a_se_ (None, 1, 1, 40)     842         prune_low_magnitude_block1a_se_re
# __________________________________________________________________________________________________
# prune_low_magnitude_block1a_se_ (None, None, None, 4 1           prune_low_magnitude_block1a_activ
#                                                                  prune_low_magnitude_block1a_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block1a_pro (None, None, None, 2 1922        prune_low_magnitude_block1a_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block1a_pro (None, None, None, 2 97          prune_low_magnitude_block1a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block1b_dwc (None, None, None, 2 217         prune_low_magnitude_block1a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block1b_bn  (None, None, None, 2 97          prune_low_magnitude_block1b_dwcon
# __________________________________________________________________________________________________
# prune_low_magnitude_block1b_act (None, None, None, 2 1           prune_low_magnitude_block1b_bn[0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block1b_se_ (None, 24)           1           prune_low_magnitude_block1b_activ
# __________________________________________________________________________________________________
# prune_low_magnitude_block1b_se_ (None, 1, 1, 24)     1           prune_low_magnitude_block1b_se_sq
# __________________________________________________________________________________________________
# prune_low_magnitude_block1b_se_ (None, 1, 1, 6)      296         prune_low_magnitude_block1b_se_re
# __________________________________________________________________________________________________
# prune_low_magnitude_block1b_se_ (None, 1, 1, 24)     314         prune_low_magnitude_block1b_se_re
# __________________________________________________________________________________________________
# prune_low_magnitude_block1b_se_ (None, None, None, 2 1           prune_low_magnitude_block1b_activ
#                                                                  prune_low_magnitude_block1b_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block1b_pro (None, None, None, 2 1154        prune_low_magnitude_block1b_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block1b_pro (None, None, None, 2 97          prune_low_magnitude_block1b_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block1b_dro (None, None, None, 2 1           prune_low_magnitude_block1b_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block1b_add (None, None, None, 2 1           prune_low_magnitude_block1b_drop[
#                                                                  prune_low_magnitude_block1a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block2a_exp (None, None, None, 1 6914        prune_low_magnitude_block1b_add[0
# __________________________________________________________________________________________________
# prune_low_magnitude_block2a_exp (None, None, None, 1 577         prune_low_magnitude_block2a_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block2a_exp (None, None, None, 1 1           prune_low_magnitude_block2a_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block2a_dwc (None, None, None, 1 1297        prune_low_magnitude_block2a_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block2a_bn  (None, None, None, 1 577         prune_low_magnitude_block2a_dwcon
# __________________________________________________________________________________________________
# prune_low_magnitude_block2a_act (None, None, None, 1 1           prune_low_magnitude_block2a_bn[0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block2a_se_ (None, 144)          1           prune_low_magnitude_block2a_activ
# __________________________________________________________________________________________________
# prune_low_magnitude_block2a_se_ (None, 1, 1, 144)    1           prune_low_magnitude_block2a_se_sq
# __________________________________________________________________________________________________
# prune_low_magnitude_block2a_se_ (None, 1, 1, 6)      1736        prune_low_magnitude_block2a_se_re
# __________________________________________________________________________________________________
# prune_low_magnitude_block2a_se_ (None, 1, 1, 144)    1874        prune_low_magnitude_block2a_se_re
# __________________________________________________________________________________________________
# prune_low_magnitude_block2a_se_ (None, None, None, 1 1           prune_low_magnitude_block2a_activ
#                                                                  prune_low_magnitude_block2a_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block2a_pro (None, None, None, 3 9218        prune_low_magnitude_block2a_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block2a_pro (None, None, None, 3 129         prune_low_magnitude_block2a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block2b_exp (None, None, None, 1 12290       prune_low_magnitude_block2a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block2b_exp (None, None, None, 1 769         prune_low_magnitude_block2b_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block2b_exp (None, None, None, 1 1           prune_low_magnitude_block2b_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block2b_dwc (None, None, None, 1 1729        prune_low_magnitude_block2b_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block2b_bn  (None, None, None, 1 769         prune_low_magnitude_block2b_dwcon
# __________________________________________________________________________________________________
# prune_low_magnitude_block2b_act (None, None, None, 1 1           prune_low_magnitude_block2b_bn[0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block2b_se_ (None, 192)          1           prune_low_magnitude_block2b_activ
# __________________________________________________________________________________________________
# prune_low_magnitude_block2b_se_ (None, 1, 1, 192)    1           prune_low_magnitude_block2b_se_sq
# __________________________________________________________________________________________________
# prune_low_magnitude_block2b_se_ (None, 1, 1, 8)      3082        prune_low_magnitude_block2b_se_re
# __________________________________________________________________________________________________
# prune_low_magnitude_block2b_se_ (None, 1, 1, 192)    3266        prune_low_magnitude_block2b_se_re
# __________________________________________________________________________________________________
# prune_low_magnitude_block2b_se_ (None, None, None, 1 1           prune_low_magnitude_block2b_activ
#                                                                  prune_low_magnitude_block2b_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block2b_pro (None, None, None, 3 12290       prune_low_magnitude_block2b_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block2b_pro (None, None, None, 3 129         prune_low_magnitude_block2b_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block2b_dro (None, None, None, 3 1           prune_low_magnitude_block2b_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block2b_add (None, None, None, 3 1           prune_low_magnitude_block2b_drop[
#                                                                  prune_low_magnitude_block2a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block2c_exp (None, None, None, 1 12290       prune_low_magnitude_block2b_add[0
# __________________________________________________________________________________________________
# prune_low_magnitude_block2c_exp (None, None, None, 1 769         prune_low_magnitude_block2c_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block2c_exp (None, None, None, 1 1           prune_low_magnitude_block2c_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block2c_dwc (None, None, None, 1 1729        prune_low_magnitude_block2c_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block2c_bn  (None, None, None, 1 769         prune_low_magnitude_block2c_dwcon
# __________________________________________________________________________________________________
# prune_low_magnitude_block2c_act (None, None, None, 1 1           prune_low_magnitude_block2c_bn[0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block2c_se_ (None, 192)          1           prune_low_magnitude_block2c_activ
# __________________________________________________________________________________________________
# prune_low_magnitude_block2c_se_ (None, 1, 1, 192)    1           prune_low_magnitude_block2c_se_sq
# __________________________________________________________________________________________________
# prune_low_magnitude_block2c_se_ (None, 1, 1, 8)      3082        prune_low_magnitude_block2c_se_re
# __________________________________________________________________________________________________
# prune_low_magnitude_block2c_se_ (None, 1, 1, 192)    3266        prune_low_magnitude_block2c_se_re
# __________________________________________________________________________________________________
# prune_low_magnitude_block2c_se_ (None, None, None, 1 1           prune_low_magnitude_block2c_activ
#                                                                  prune_low_magnitude_block2c_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block2c_pro (None, None, None, 3 12290       prune_low_magnitude_block2c_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block2c_pro (None, None, None, 3 129         prune_low_magnitude_block2c_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block2c_dro (None, None, None, 3 1           prune_low_magnitude_block2c_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block2c_add (None, None, None, 3 1           prune_low_magnitude_block2c_drop[
#                                                                  prune_low_magnitude_block2b_add[0
# __________________________________________________________________________________________________
# prune_low_magnitude_block3a_exp (None, None, None, 1 12290       prune_low_magnitude_block2c_add[0
# __________________________________________________________________________________________________
# prune_low_magnitude_block3a_exp (None, None, None, 1 769         prune_low_magnitude_block3a_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block3a_exp (None, None, None, 1 1           prune_low_magnitude_block3a_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block3a_dwc (None, None, None, 1 4801        prune_low_magnitude_block3a_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block3a_bn  (None, None, None, 1 769         prune_low_magnitude_block3a_dwcon
# __________________________________________________________________________________________________
# prune_low_magnitude_block3a_act (None, None, None, 1 1           prune_low_magnitude_block3a_bn[0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block3a_se_ (None, 192)          1           prune_low_magnitude_block3a_activ
# __________________________________________________________________________________________________
# prune_low_magnitude_block3a_se_ (None, 1, 1, 192)    1           prune_low_magnitude_block3a_se_sq
# __________________________________________________________________________________________________
# prune_low_magnitude_block3a_se_ (None, 1, 1, 8)      3082        prune_low_magnitude_block3a_se_re
# __________________________________________________________________________________________________
# prune_low_magnitude_block3a_se_ (None, 1, 1, 192)    3266        prune_low_magnitude_block3a_se_re
# __________________________________________________________________________________________________
# prune_low_magnitude_block3a_se_ (None, None, None, 1 1           prune_low_magnitude_block3a_activ
#                                                                  prune_low_magnitude_block3a_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block3a_pro (None, None, None, 4 18434       prune_low_magnitude_block3a_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block3a_pro (None, None, None, 4 193         prune_low_magnitude_block3a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block3b_exp (None, None, None, 2 27650       prune_low_magnitude_block3a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block3b_exp (None, None, None, 2 1153        prune_low_magnitude_block3b_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block3b_exp (None, None, None, 2 1           prune_low_magnitude_block3b_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block3b_dwc (None, None, None, 2 7201        prune_low_magnitude_block3b_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block3b_bn  (None, None, None, 2 1153        prune_low_magnitude_block3b_dwcon
# __________________________________________________________________________________________________
# prune_low_magnitude_block3b_act (None, None, None, 2 1           prune_low_magnitude_block3b_bn[0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block3b_se_ (None, 288)          1           prune_low_magnitude_block3b_activ
# __________________________________________________________________________________________________
# prune_low_magnitude_block3b_se_ (None, 1, 1, 288)    1           prune_low_magnitude_block3b_se_sq
# __________________________________________________________________________________________________
# prune_low_magnitude_block3b_se_ (None, 1, 1, 12)     6926        prune_low_magnitude_block3b_se_re
# __________________________________________________________________________________________________
# prune_low_magnitude_block3b_se_ (None, 1, 1, 288)    7202        prune_low_magnitude_block3b_se_re
# __________________________________________________________________________________________________
# prune_low_magnitude_block3b_se_ (None, None, None, 2 1           prune_low_magnitude_block3b_activ
#                                                                  prune_low_magnitude_block3b_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block3b_pro (None, None, None, 4 27650       prune_low_magnitude_block3b_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block3b_pro (None, None, None, 4 193         prune_low_magnitude_block3b_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block3b_dro (None, None, None, 4 1           prune_low_magnitude_block3b_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block3b_add (None, None, None, 4 1           prune_low_magnitude_block3b_drop[
#                                                                  prune_low_magnitude_block3a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block3c_exp (None, None, None, 2 27650       prune_low_magnitude_block3b_add[0
# __________________________________________________________________________________________________
# prune_low_magnitude_block3c_exp (None, None, None, 2 1153        prune_low_magnitude_block3c_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block3c_exp (None, None, None, 2 1           prune_low_magnitude_block3c_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block3c_dwc (None, None, None, 2 7201        prune_low_magnitude_block3c_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block3c_bn  (None, None, None, 2 1153        prune_low_magnitude_block3c_dwcon
# __________________________________________________________________________________________________
# prune_low_magnitude_block3c_act (None, None, None, 2 1           prune_low_magnitude_block3c_bn[0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block3c_se_ (None, 288)          1           prune_low_magnitude_block3c_activ
# __________________________________________________________________________________________________
# prune_low_magnitude_block3c_se_ (None, 1, 1, 288)    1           prune_low_magnitude_block3c_se_sq
# __________________________________________________________________________________________________
# prune_low_magnitude_block3c_se_ (None, 1, 1, 12)     6926        prune_low_magnitude_block3c_se_re
# __________________________________________________________________________________________________
# prune_low_magnitude_block3c_se_ (None, 1, 1, 288)    7202        prune_low_magnitude_block3c_se_re
# __________________________________________________________________________________________________
# prune_low_magnitude_block3c_se_ (None, None, None, 2 1           prune_low_magnitude_block3c_activ
#                                                                  prune_low_magnitude_block3c_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block3c_pro (None, None, None, 4 27650       prune_low_magnitude_block3c_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block3c_pro (None, None, None, 4 193         prune_low_magnitude_block3c_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block3c_dro (None, None, None, 4 1           prune_low_magnitude_block3c_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block3c_add (None, None, None, 4 1           prune_low_magnitude_block3c_drop[
#                                                                  prune_low_magnitude_block3b_add[0
# __________________________________________________________________________________________________
# prune_low_magnitude_block4a_exp (None, None, None, 2 27650       prune_low_magnitude_block3c_add[0
# __________________________________________________________________________________________________
# prune_low_magnitude_block4a_exp (None, None, None, 2 1153        prune_low_magnitude_block4a_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block4a_exp (None, None, None, 2 1           prune_low_magnitude_block4a_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block4a_dwc (None, None, None, 2 2593        prune_low_magnitude_block4a_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block4a_bn  (None, None, None, 2 1153        prune_low_magnitude_block4a_dwcon
# __________________________________________________________________________________________________
# prune_low_magnitude_block4a_act (None, None, None, 2 1           prune_low_magnitude_block4a_bn[0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4a_se_ (None, 288)          1           prune_low_magnitude_block4a_activ
# __________________________________________________________________________________________________
# prune_low_magnitude_block4a_se_ (None, 1, 1, 288)    1           prune_low_magnitude_block4a_se_sq
# __________________________________________________________________________________________________
# prune_low_magnitude_block4a_se_ (None, 1, 1, 12)     6926        prune_low_magnitude_block4a_se_re
# __________________________________________________________________________________________________
# prune_low_magnitude_block4a_se_ (None, 1, 1, 288)    7202        prune_low_magnitude_block4a_se_re
# __________________________________________________________________________________________________
# prune_low_magnitude_block4a_se_ (None, None, None, 2 1           prune_low_magnitude_block4a_activ
#                                                                  prune_low_magnitude_block4a_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block4a_pro (None, None, None, 9 55298       prune_low_magnitude_block4a_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block4a_pro (None, None, None, 9 385         prune_low_magnitude_block4a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block4b_exp (None, None, None, 5 110594      prune_low_magnitude_block4a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block4b_exp (None, None, None, 5 2305        prune_low_magnitude_block4b_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block4b_exp (None, None, None, 5 1           prune_low_magnitude_block4b_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block4b_dwc (None, None, None, 5 5185        prune_low_magnitude_block4b_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block4b_bn  (None, None, None, 5 2305        prune_low_magnitude_block4b_dwcon
# __________________________________________________________________________________________________
# prune_low_magnitude_block4b_act (None, None, None, 5 1           prune_low_magnitude_block4b_bn[0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4b_se_ (None, 576)          1           prune_low_magnitude_block4b_activ
# __________________________________________________________________________________________________
# prune_low_magnitude_block4b_se_ (None, 1, 1, 576)    1           prune_low_magnitude_block4b_se_sq
# __________________________________________________________________________________________________
# prune_low_magnitude_block4b_se_ (None, 1, 1, 24)     27674       prune_low_magnitude_block4b_se_re
# __________________________________________________________________________________________________
# prune_low_magnitude_block4b_se_ (None, 1, 1, 576)    28226       prune_low_magnitude_block4b_se_re
# __________________________________________________________________________________________________
# prune_low_magnitude_block4b_se_ (None, None, None, 5 1           prune_low_magnitude_block4b_activ
#                                                                  prune_low_magnitude_block4b_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block4b_pro (None, None, None, 9 110594      prune_low_magnitude_block4b_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block4b_pro (None, None, None, 9 385         prune_low_magnitude_block4b_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block4b_dro (None, None, None, 9 1           prune_low_magnitude_block4b_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block4b_add (None, None, None, 9 1           prune_low_magnitude_block4b_drop[
#                                                                  prune_low_magnitude_block4a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block4c_exp (None, None, None, 5 110594      prune_low_magnitude_block4b_add[0
# __________________________________________________________________________________________________
# prune_low_magnitude_block4c_exp (None, None, None, 5 2305        prune_low_magnitude_block4c_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block4c_exp (None, None, None, 5 1           prune_low_magnitude_block4c_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block4c_dwc (None, None, None, 5 5185        prune_low_magnitude_block4c_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block4c_bn  (None, None, None, 5 2305        prune_low_magnitude_block4c_dwcon
# __________________________________________________________________________________________________
# prune_low_magnitude_block4c_act (None, None, None, 5 1           prune_low_magnitude_block4c_bn[0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4c_se_ (None, 576)          1           prune_low_magnitude_block4c_activ
# __________________________________________________________________________________________________
# prune_low_magnitude_block4c_se_ (None, 1, 1, 576)    1           prune_low_magnitude_block4c_se_sq
# __________________________________________________________________________________________________
# prune_low_magnitude_block4c_se_ (None, 1, 1, 24)     27674       prune_low_magnitude_block4c_se_re
# __________________________________________________________________________________________________
# prune_low_magnitude_block4c_se_ (None, 1, 1, 576)    28226       prune_low_magnitude_block4c_se_re
# __________________________________________________________________________________________________
# prune_low_magnitude_block4c_se_ (None, None, None, 5 1           prune_low_magnitude_block4c_activ
#                                                                  prune_low_magnitude_block4c_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block4c_pro (None, None, None, 9 110594      prune_low_magnitude_block4c_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block4c_pro (None, None, None, 9 385         prune_low_magnitude_block4c_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block4c_dro (None, None, None, 9 1           prune_low_magnitude_block4c_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block4c_add (None, None, None, 9 1           prune_low_magnitude_block4c_drop[
#                                                                  prune_low_magnitude_block4b_add[0
# __________________________________________________________________________________________________
# prune_low_magnitude_block4d_exp (None, None, None, 5 110594      prune_low_magnitude_block4c_add[0
# __________________________________________________________________________________________________
# prune_low_magnitude_block4d_exp (None, None, None, 5 2305        prune_low_magnitude_block4d_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block4d_exp (None, None, None, 5 1           prune_low_magnitude_block4d_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block4d_dwc (None, None, None, 5 5185        prune_low_magnitude_block4d_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block4d_bn  (None, None, None, 5 2305        prune_low_magnitude_block4d_dwcon
# __________________________________________________________________________________________________
# prune_low_magnitude_block4d_act (None, None, None, 5 1           prune_low_magnitude_block4d_bn[0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4d_se_ (None, 576)          1           prune_low_magnitude_block4d_activ
# __________________________________________________________________________________________________
# prune_low_magnitude_block4d_se_ (None, 1, 1, 576)    1           prune_low_magnitude_block4d_se_sq
# __________________________________________________________________________________________________
# prune_low_magnitude_block4d_se_ (None, 1, 1, 24)     27674       prune_low_magnitude_block4d_se_re
# __________________________________________________________________________________________________
# prune_low_magnitude_block4d_se_ (None, 1, 1, 576)    28226       prune_low_magnitude_block4d_se_re
# __________________________________________________________________________________________________
# prune_low_magnitude_block4d_se_ (None, None, None, 5 1           prune_low_magnitude_block4d_activ
#                                                                  prune_low_magnitude_block4d_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block4d_pro (None, None, None, 9 110594      prune_low_magnitude_block4d_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block4d_pro (None, None, None, 9 385         prune_low_magnitude_block4d_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block4d_dro (None, None, None, 9 1           prune_low_magnitude_block4d_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block4d_add (None, None, None, 9 1           prune_low_magnitude_block4d_drop[
#                                                                  prune_low_magnitude_block4c_add[0
# __________________________________________________________________________________________________
# prune_low_magnitude_block4e_exp (None, None, None, 5 110594      prune_low_magnitude_block4d_add[0
# __________________________________________________________________________________________________
# prune_low_magnitude_block4e_exp (None, None, None, 5 2305        prune_low_magnitude_block4e_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block4e_exp (None, None, None, 5 1           prune_low_magnitude_block4e_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block4e_dwc (None, None, None, 5 5185        prune_low_magnitude_block4e_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block4e_bn  (None, None, None, 5 2305        prune_low_magnitude_block4e_dwcon
# __________________________________________________________________________________________________
# prune_low_magnitude_block4e_act (None, None, None, 5 1           prune_low_magnitude_block4e_bn[0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block4e_se_ (None, 576)          1           prune_low_magnitude_block4e_activ
# __________________________________________________________________________________________________
# prune_low_magnitude_block4e_se_ (None, 1, 1, 576)    1           prune_low_magnitude_block4e_se_sq
# __________________________________________________________________________________________________
# prune_low_magnitude_block4e_se_ (None, 1, 1, 24)     27674       prune_low_magnitude_block4e_se_re
# __________________________________________________________________________________________________
# prune_low_magnitude_block4e_se_ (None, 1, 1, 576)    28226       prune_low_magnitude_block4e_se_re
# __________________________________________________________________________________________________
# prune_low_magnitude_block4e_se_ (None, None, None, 5 1           prune_low_magnitude_block4e_activ
#                                                                  prune_low_magnitude_block4e_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block4e_pro (None, None, None, 9 110594      prune_low_magnitude_block4e_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block4e_pro (None, None, None, 9 385         prune_low_magnitude_block4e_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block4e_dro (None, None, None, 9 1           prune_low_magnitude_block4e_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block4e_add (None, None, None, 9 1           prune_low_magnitude_block4e_drop[
#                                                                  prune_low_magnitude_block4d_add[0
# __________________________________________________________________________________________________
# prune_low_magnitude_block5a_exp (None, None, None, 5 110594      prune_low_magnitude_block4e_add[0
# __________________________________________________________________________________________________
# prune_low_magnitude_block5a_exp (None, None, None, 5 2305        prune_low_magnitude_block5a_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block5a_exp (None, None, None, 5 1           prune_low_magnitude_block5a_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block5a_dwc (None, None, None, 5 14401       prune_low_magnitude_block5a_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block5a_bn  (None, None, None, 5 2305        prune_low_magnitude_block5a_dwcon
# __________________________________________________________________________________________________
# prune_low_magnitude_block5a_act (None, None, None, 5 1           prune_low_magnitude_block5a_bn[0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5a_se_ (None, 576)          1           prune_low_magnitude_block5a_activ
# __________________________________________________________________________________________________
# prune_low_magnitude_block5a_se_ (None, 1, 1, 576)    1           prune_low_magnitude_block5a_se_sq
# __________________________________________________________________________________________________
# prune_low_magnitude_block5a_se_ (None, 1, 1, 24)     27674       prune_low_magnitude_block5a_se_re
# __________________________________________________________________________________________________
# prune_low_magnitude_block5a_se_ (None, 1, 1, 576)    28226       prune_low_magnitude_block5a_se_re
# __________________________________________________________________________________________________
# prune_low_magnitude_block5a_se_ (None, None, None, 5 1           prune_low_magnitude_block5a_activ
#                                                                  prune_low_magnitude_block5a_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block5a_pro (None, None, None, 1 156674      prune_low_magnitude_block5a_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block5a_pro (None, None, None, 1 545         prune_low_magnitude_block5a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block5b_exp (None, None, None, 8 221954      prune_low_magnitude_block5a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block5b_exp (None, None, None, 8 3265        prune_low_magnitude_block5b_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block5b_exp (None, None, None, 8 1           prune_low_magnitude_block5b_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block5b_dwc (None, None, None, 8 20401       prune_low_magnitude_block5b_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block5b_bn  (None, None, None, 8 3265        prune_low_magnitude_block5b_dwcon
# __________________________________________________________________________________________________
# prune_low_magnitude_block5b_act (None, None, None, 8 1           prune_low_magnitude_block5b_bn[0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5b_se_ (None, 816)          1           prune_low_magnitude_block5b_activ
# __________________________________________________________________________________________________
# prune_low_magnitude_block5b_se_ (None, 1, 1, 816)    1           prune_low_magnitude_block5b_se_sq
# __________________________________________________________________________________________________
# prune_low_magnitude_block5b_se_ (None, 1, 1, 34)     55524       prune_low_magnitude_block5b_se_re
# __________________________________________________________________________________________________
# prune_low_magnitude_block5b_se_ (None, 1, 1, 816)    56306       prune_low_magnitude_block5b_se_re
# __________________________________________________________________________________________________
# prune_low_magnitude_block5b_se_ (None, None, None, 8 1           prune_low_magnitude_block5b_activ
#                                                                  prune_low_magnitude_block5b_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block5b_pro (None, None, None, 1 221954      prune_low_magnitude_block5b_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block5b_pro (None, None, None, 1 545         prune_low_magnitude_block5b_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block5b_dro (None, None, None, 1 1           prune_low_magnitude_block5b_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block5b_add (None, None, None, 1 1           prune_low_magnitude_block5b_drop[
#                                                                  prune_low_magnitude_block5a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block5c_exp (None, None, None, 8 221954      prune_low_magnitude_block5b_add[0
# __________________________________________________________________________________________________
# prune_low_magnitude_block5c_exp (None, None, None, 8 3265        prune_low_magnitude_block5c_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block5c_exp (None, None, None, 8 1           prune_low_magnitude_block5c_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block5c_dwc (None, None, None, 8 20401       prune_low_magnitude_block5c_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block5c_bn  (None, None, None, 8 3265        prune_low_magnitude_block5c_dwcon
# __________________________________________________________________________________________________
# prune_low_magnitude_block5c_act (None, None, None, 8 1           prune_low_magnitude_block5c_bn[0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block5c_se_ (None, 816)          1           prune_low_magnitude_block5c_activ
# __________________________________________________________________________________________________
# prune_low_magnitude_block5c_se_ (None, 1, 1, 816)    1           prune_low_magnitude_block5c_se_sq
# __________________________________________________________________________________________________
# prune_low_magnitude_block5c_se_ (None, 1, 1, 34)     55524       prune_low_magnitude_block5c_se_re
# __________________________________________________________________________________________________
# prune_low_magnitude_block5c_se_ (None, 1, 1, 816)    56306       prune_low_magnitude_block5c_se_re
# __________________________________________________________________________________________________
# prune_low_magnitude_block5c_se_ (None, None, None, 8 1           prune_low_magnitude_block5c_activ
#                                                                  prune_low_magnitude_block5c_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block5c_pro (None, None, None, 1 221954      prune_low_magnitude_block5c_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block5c_pro (None, None, None, 1 545         prune_low_magnitude_block5c_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block5c_dro (None, None, None, 1 1           prune_low_magnitude_block5c_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block5c_add (None, None, None, 1 1           prune_low_magnitude_block5c_drop[
# ...
# __________________________________________________________________________________________________
# prune_low_magnitude_block6f_pro (None, None, None, 2 929         prune_low_magnitude_block6f_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block6f_dro (None, None, None, 2 1           prune_low_magnitude_block6f_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block6f_add (None, None, None, 2 1           prune_low_magnitude_block6f_drop[
#                                                                  prune_low_magnitude_block6e_add[0
# __________________________________________________________________________________________________
# prune_low_magnitude_block7a_exp (None, None, None, 1 645890      prune_low_magnitude_block6f_add[0
# __________________________________________________________________________________________________
# prune_low_magnitude_block7a_exp (None, None, None, 1 5569        prune_low_magnitude_block7a_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block7a_exp (None, None, None, 1 1           prune_low_magnitude_block7a_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block7a_dwc (None, None, None, 1 12529       prune_low_magnitude_block7a_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block7a_bn  (None, None, None, 1 5569        prune_low_magnitude_block7a_dwcon
# __________________________________________________________________________________________________
# prune_low_magnitude_block7a_act (None, None, None, 1 1           prune_low_magnitude_block7a_bn[0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block7a_se_ (None, 1392)         1           prune_low_magnitude_block7a_activ
# __________________________________________________________________________________________________
# prune_low_magnitude_block7a_se_ (None, 1, 1, 1392)   1           prune_low_magnitude_block7a_se_sq
# __________________________________________________________________________________________________
# prune_low_magnitude_block7a_se_ (None, 1, 1, 58)     161532      prune_low_magnitude_block7a_se_re
# __________________________________________________________________________________________________
# prune_low_magnitude_block7a_se_ (None, 1, 1, 1392)   162866      prune_low_magnitude_block7a_se_re
# __________________________________________________________________________________________________
# prune_low_magnitude_block7a_se_ (None, None, None, 1 1           prune_low_magnitude_block7a_activ
#                                                                  prune_low_magnitude_block7a_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block7a_pro (None, None, None, 3 1069058     prune_low_magnitude_block7a_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block7a_pro (None, None, None, 3 1537        prune_low_magnitude_block7a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block7b_exp (None, None, None, 2 1769474     prune_low_magnitude_block7a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block7b_exp (None, None, None, 2 9217        prune_low_magnitude_block7b_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block7b_exp (None, None, None, 2 1           prune_low_magnitude_block7b_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block7b_dwc (None, None, None, 2 20737       prune_low_magnitude_block7b_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_block7b_bn  (None, None, None, 2 9217        prune_low_magnitude_block7b_dwcon
# __________________________________________________________________________________________________
# prune_low_magnitude_block7b_act (None, None, None, 2 1           prune_low_magnitude_block7b_bn[0]
# __________________________________________________________________________________________________
# prune_low_magnitude_block7b_se_ (None, 2304)         1           prune_low_magnitude_block7b_activ
# __________________________________________________________________________________________________
# prune_low_magnitude_block7b_se_ (None, 1, 1, 2304)   1           prune_low_magnitude_block7b_se_sq
# __________________________________________________________________________________________________
# prune_low_magnitude_block7b_se_ (None, 1, 1, 96)     442466      prune_low_magnitude_block7b_se_re
# __________________________________________________________________________________________________
# prune_low_magnitude_block7b_se_ (None, 1, 1, 2304)   444674      prune_low_magnitude_block7b_se_re
# __________________________________________________________________________________________________
# prune_low_magnitude_block7b_se_ (None, None, None, 2 1           prune_low_magnitude_block7b_activ
#                                                                  prune_low_magnitude_block7b_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block7b_pro (None, None, None, 3 1769474     prune_low_magnitude_block7b_se_ex
# __________________________________________________________________________________________________
# prune_low_magnitude_block7b_pro (None, None, None, 3 1537        prune_low_magnitude_block7b_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block7b_dro (None, None, None, 3 1           prune_low_magnitude_block7b_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_block7b_add (None, None, None, 3 1           prune_low_magnitude_block7b_drop[
#                                                                  prune_low_magnitude_block7a_proje
# __________________________________________________________________________________________________
# prune_low_magnitude_top_conv (P (None, None, None, 1 1179650     prune_low_magnitude_block7b_add[0
# __________________________________________________________________________________________________
# prune_low_magnitude_top_bn (Pru (None, None, None, 1 6145        prune_low_magnitude_top_conv[0][0
# __________________________________________________________________________________________________
# prune_low_magnitude_top_activat (None, None, None, 1 1           prune_low_magnitude_top_bn[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_decoder_sta (None, None, None, 1 1           prune_low_magnitude_top_activatio
# __________________________________________________________________________________________________
# prune_low_magnitude_decoder_sta (None, None, None, 2 1           prune_low_magnitude_decoder_stage
#                                                                  prune_low_magnitude_block6a_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_decoder_sta (None, None, None, 2 10838018    prune_low_magnitude_decoder_stage
# __________________________________________________________________________________________________
# prune_low_magnitude_decoder_sta (None, None, None, 2 1025        prune_low_magnitude_decoder_stage
# __________________________________________________________________________________________________
# prune_low_magnitude_decoder_sta (None, None, None, 2 1           prune_low_magnitude_decoder_stage
# __________________________________________________________________________________________________
# prune_low_magnitude_decoder_sta (None, None, None, 2 1179650     prune_low_magnitude_decoder_stage
# __________________________________________________________________________________________________
# prune_low_magnitude_decoder_sta (None, None, None, 2 1025        prune_low_magnitude_decoder_stage
# __________________________________________________________________________________________________
# prune_low_magnitude_decoder_sta (None, None, None, 2 1           prune_low_magnitude_decoder_stage
# __________________________________________________________________________________________________
# prune_low_magnitude_decoder_sta (None, None, None, 2 1           prune_low_magnitude_decoder_stage
# __________________________________________________________________________________________________
# prune_low_magnitude_decoder_sta (None, None, None, 5 1           prune_low_magnitude_decoder_stage
#                                                                  prune_low_magnitude_block4a_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_decoder_sta (None, None, None, 1 1253378     prune_low_magnitude_decoder_stage
# __________________________________________________________________________________________________
# prune_low_magnitude_decoder_sta (None, None, None, 1 513         prune_low_magnitude_decoder_stage
# __________________________________________________________________________________________________
# prune_low_magnitude_decoder_sta (None, None, None, 1 1           prune_low_magnitude_decoder_stage
# __________________________________________________________________________________________________
# prune_low_magnitude_decoder_sta (None, None, None, 1 294914      prune_low_magnitude_decoder_stage
# __________________________________________________________________________________________________
# prune_low_magnitude_decoder_sta (None, None, None, 1 513         prune_low_magnitude_decoder_stage
# __________________________________________________________________________________________________
# prune_low_magnitude_decoder_sta (None, None, None, 1 1           prune_low_magnitude_decoder_stage
# __________________________________________________________________________________________________
# prune_low_magnitude_decoder_sta (None, None, None, 1 1           prune_low_magnitude_decoder_stage
# __________________________________________________________________________________________________
# prune_low_magnitude_decoder_sta (None, None, None, 3 1           prune_low_magnitude_decoder_stage
#                                                                  prune_low_magnitude_block3a_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_decoder_sta (None, None, None, 6 368642      prune_low_magnitude_decoder_stage
# __________________________________________________________________________________________________
# prune_low_magnitude_decoder_sta (None, None, None, 6 257         prune_low_magnitude_decoder_stage
# __________________________________________________________________________________________________
# prune_low_magnitude_decoder_sta (None, None, None, 6 1           prune_low_magnitude_decoder_stage
# __________________________________________________________________________________________________
# prune_low_magnitude_decoder_sta (None, None, None, 6 73730       prune_low_magnitude_decoder_stage
# __________________________________________________________________________________________________
# prune_low_magnitude_decoder_sta (None, None, None, 6 257         prune_low_magnitude_decoder_stage
# __________________________________________________________________________________________________
# prune_low_magnitude_decoder_sta (None, None, None, 6 1           prune_low_magnitude_decoder_stage
# __________________________________________________________________________________________________
# prune_low_magnitude_decoder_sta (None, None, None, 6 1           prune_low_magnitude_decoder_stage
# __________________________________________________________________________________________________
# prune_low_magnitude_decoder_sta (None, None, None, 2 1           prune_low_magnitude_decoder_stage
#                                                                  prune_low_magnitude_block2a_expan
# __________________________________________________________________________________________________
# prune_low_magnitude_decoder_sta (None, None, None, 3 119810      prune_low_magnitude_decoder_stage
# __________________________________________________________________________________________________
# prune_low_magnitude_decoder_sta (None, None, None, 3 129         prune_low_magnitude_decoder_stage
# __________________________________________________________________________________________________
# prune_low_magnitude_decoder_sta (None, None, None, 3 1           prune_low_magnitude_decoder_stage
# __________________________________________________________________________________________________
# prune_low_magnitude_decoder_sta (None, None, None, 3 18434       prune_low_magnitude_decoder_stage
# __________________________________________________________________________________________________
# prune_low_magnitude_decoder_sta (None, None, None, 3 129         prune_low_magnitude_decoder_stage
# __________________________________________________________________________________________________
# prune_low_magnitude_decoder_sta (None, None, None, 3 1           prune_low_magnitude_decoder_stage
# __________________________________________________________________________________________________
# prune_low_magnitude_decoder_sta (None, None, None, 3 1           prune_low_magnitude_decoder_stage
# __________________________________________________________________________________________________
# prune_low_magnitude_decoder_sta (None, None, None, 1 9218        prune_low_magnitude_decoder_stage
# __________________________________________________________________________________________________
# prune_low_magnitude_decoder_sta (None, None, None, 1 65          prune_low_magnitude_decoder_stage
# __________________________________________________________________________________________________
# prune_low_magnitude_decoder_sta (None, None, None, 1 1           prune_low_magnitude_decoder_stage
# __________________________________________________________________________________________________
# prune_low_magnitude_decoder_sta (None, None, None, 1 4610        prune_low_magnitude_decoder_stage
# __________________________________________________________________________________________________
# prune_low_magnitude_decoder_sta (None, None, None, 1 65          prune_low_magnitude_decoder_stage
# __________________________________________________________________________________________________
# prune_low_magnitude_decoder_sta (None, None, None, 1 1           prune_low_magnitude_decoder_stage
# __________________________________________________________________________________________________
# prune_low_magnitude_final_conv  (None, None, None, 1 291         prune_low_magnitude_decoder_stage
# __________________________________________________________________________________________________
# prune_low_magnitude_sigmoid (Pr (None, None, None, 1 1           prune_low_magnitude_final_conv[0]
# ==================================================================================================
# Total params: 35,166,037
# Trainable params: 17,778,553
# Non-trainable params: 17,387,484
# __________________________________________________________________________________________________

# %%
model_for_prun = compile_model(sub_model_for_prun)
model_for_prun.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, None, None, 1)]   0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, None, None, 3)     6
# _________________________________________________________________
# model (Model)                (None, None, None, 1)     35166037
# =================================================================
# Total params: 35,166,043
# Trainable params: 17,778,559
# Non-trainable params: 17,387,484
# _________________________________________________________________

# %%
callbacks = [
    tfmot.sparsity.keras.UpdatePruningStep(),
    # Log sparsity and other metrics in Tensorboard.
    tfmot.sparsity.keras.PruningSummaries(log_dir=str(TRAIN_LOGS_FOLDER_PATH)),
    tf.keras.callbacks.ModelCheckpoint(str(TRAIN_LOGS_FOLDER_PATH) + "/pruning_model_{epoch:02d}.h5",
                                                      save_best_only=False,
                                                      save_weights_only=False,
                                                      verbose=1
                                                      )
]

model_for_prun.fit_generator(train_dataloader,
                    steps_per_epoch=STEPS_PER_EPOCH,
                    epochs=2,
                    validation_data=valid_dataloader,
                    callbacks=callbacks,
                    validation_steps=STEPS_VALID
                    )
# Out:
# Epoch 1/2
# Epoch 1/2
#  31/260 [==>...........................] - ETA: 4:08 - loss: 0.0535 - iou_score: 0.9718 - f1-score: 0.9855
# Epoch 00001: saving model to train_logs/pruning_model_01.h5
# 260/260 [==============================] - 711s 3s/step - loss: 0.0448 - iou_score: 0.9622 - f1-score: 0.9803 - val_loss: 0.0535 - val_iou_score: 0.9718 - val_f1-score: 0.9855
# Epoch 2/2
# Epoch 1/2
#  31/260 [==>...........................] - ETA: 22s - loss: 0.0511 - iou_score: 0.9710 - f1-score: 0.9851
# Epoch 00002: saving model to train_logs/pruning_model_02.h5
# 260/260 [==============================] - 308s 1s/step - loss: 0.0411 - iou_score: 0.9613 - f1-score: 0.9799 - val_loss: 0.0511 - val_iou_score: 0.9710 - val_f1-score: 0.9851

# %%
print('[MODEL PRUNED]')
sub_model_for_prun.set_weights(model_for_prun.layers[-1].get_weights())

model_for_export = tfmot.sparsity.keras.strip_pruning(sub_model_for_prun)

print("final model")
model_for_export.summary()
# Out:
# [MODEL PRUNED]
# final model
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, None, None, 4 1080        input_1[0][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, None, None, 4 160         stem_conv[1][0]
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, None, None, 4 0           stem_bn[1][0]
# __________________________________________________________________________________________________
# block1a_dwconv (DepthwiseConv2D (None, None, None, 4 360         stem_activation[1][0]
# __________________________________________________________________________________________________
# block1a_bn (BatchNormalization) (None, None, None, 4 160         block1a_dwconv[1][0]
# __________________________________________________________________________________________________
# block1a_activation (Activation) (None, None, None, 4 0           block1a_bn[1][0]
# __________________________________________________________________________________________________
# block1a_se_squeeze (GlobalAvera (None, 40)           0           block1a_activation[1][0]
# __________________________________________________________________________________________________
# block1a_se_reshape (Reshape)    (None, 1, 1, 40)     0           block1a_se_squeeze[1][0]
# __________________________________________________________________________________________________
# block1a_se_reduce (Conv2D)      (None, 1, 1, 10)     410         block1a_se_reshape[1][0]
# __________________________________________________________________________________________________
# block1a_se_expand (Conv2D)      (None, 1, 1, 40)     440         block1a_se_reduce[1][0]
# __________________________________________________________________________________________________
# block1a_se_excite (Multiply)    (None, None, None, 4 0           block1a_activation[1][0]
#                                                                  block1a_se_expand[1][0]
# __________________________________________________________________________________________________
# block1a_project_conv (Conv2D)   (None, None, None, 2 960         block1a_se_excite[1][0]
# __________________________________________________________________________________________________
# block1a_project_bn (BatchNormal (None, None, None, 2 96          block1a_project_conv[1][0]
# __________________________________________________________________________________________________
# block1b_dwconv (DepthwiseConv2D (None, None, None, 2 216         block1a_project_bn[1][0]
# __________________________________________________________________________________________________
# block1b_bn (BatchNormalization) (None, None, None, 2 96          block1b_dwconv[1][0]
# __________________________________________________________________________________________________
# block1b_activation (Activation) (None, None, None, 2 0           block1b_bn[1][0]
# __________________________________________________________________________________________________
# block1b_se_squeeze (GlobalAvera (None, 24)           0           block1b_activation[1][0]
# __________________________________________________________________________________________________
# block1b_se_reshape (Reshape)    (None, 1, 1, 24)     0           block1b_se_squeeze[1][0]
# __________________________________________________________________________________________________
# block1b_se_reduce (Conv2D)      (None, 1, 1, 6)      150         block1b_se_reshape[1][0]
# __________________________________________________________________________________________________
# block1b_se_expand (Conv2D)      (None, 1, 1, 24)     168         block1b_se_reduce[1][0]
# __________________________________________________________________________________________________
# block1b_se_excite (Multiply)    (None, None, None, 2 0           block1b_activation[1][0]
#                                                                  block1b_se_expand[1][0]
# __________________________________________________________________________________________________
# block1b_project_conv (Conv2D)   (None, None, None, 2 576         block1b_se_excite[1][0]
# __________________________________________________________________________________________________
# block1b_project_bn (BatchNormal (None, None, None, 2 96          block1b_project_conv[1][0]
# __________________________________________________________________________________________________
# block1b_drop (FixedDropout)     (None, None, None, 2 0           block1b_project_bn[1][0]
# __________________________________________________________________________________________________
# block1b_add (Add)               (None, None, None, 2 0           block1b_drop[1][0]
#                                                                  block1a_project_bn[1][0]
# __________________________________________________________________________________________________
# block2a_expand_conv (Conv2D)    (None, None, None, 1 3456        block1b_add[1][0]
# __________________________________________________________________________________________________
# block2a_expand_bn (BatchNormali (None, None, None, 1 576         block2a_expand_conv[1][0]
# __________________________________________________________________________________________________
# block2a_expand_activation (Acti (None, None, None, 1 0           block2a_expand_bn[1][0]
# __________________________________________________________________________________________________
# block2a_dwconv (DepthwiseConv2D (None, None, None, 1 1296        block2a_expand_activation[1][0]
# __________________________________________________________________________________________________
# block2a_bn (BatchNormalization) (None, None, None, 1 576         block2a_dwconv[1][0]
# __________________________________________________________________________________________________
# block2a_activation (Activation) (None, None, None, 1 0           block2a_bn[1][0]
# __________________________________________________________________________________________________
# block2a_se_squeeze (GlobalAvera (None, 144)          0           block2a_activation[1][0]
# __________________________________________________________________________________________________
# block2a_se_reshape (Reshape)    (None, 1, 1, 144)    0           block2a_se_squeeze[1][0]
# __________________________________________________________________________________________________
# block2a_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block2a_se_reshape[1][0]
# __________________________________________________________________________________________________
# block2a_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block2a_se_reduce[1][0]
# __________________________________________________________________________________________________
# block2a_se_excite (Multiply)    (None, None, None, 1 0           block2a_activation[1][0]
#                                                                  block2a_se_expand[1][0]
# __________________________________________________________________________________________________
# block2a_project_conv (Conv2D)   (None, None, None, 3 4608        block2a_se_excite[1][0]
# __________________________________________________________________________________________________
# block2a_project_bn (BatchNormal (None, None, None, 3 128         block2a_project_conv[1][0]
# __________________________________________________________________________________________________
# block2b_expand_conv (Conv2D)    (None, None, None, 1 6144        block2a_project_bn[1][0]
# __________________________________________________________________________________________________
# block2b_expand_bn (BatchNormali (None, None, None, 1 768         block2b_expand_conv[1][0]
# __________________________________________________________________________________________________
# block2b_expand_activation (Acti (None, None, None, 1 0           block2b_expand_bn[1][0]
# __________________________________________________________________________________________________
# block2b_dwconv (DepthwiseConv2D (None, None, None, 1 1728        block2b_expand_activation[1][0]
# __________________________________________________________________________________________________
# block2b_bn (BatchNormalization) (None, None, None, 1 768         block2b_dwconv[1][0]
# __________________________________________________________________________________________________
# block2b_activation (Activation) (None, None, None, 1 0           block2b_bn[1][0]
# __________________________________________________________________________________________________
# block2b_se_squeeze (GlobalAvera (None, 192)          0           block2b_activation[1][0]
# __________________________________________________________________________________________________
# block2b_se_reshape (Reshape)    (None, 1, 1, 192)    0           block2b_se_squeeze[1][0]
# __________________________________________________________________________________________________
# block2b_se_reduce (Conv2D)      (None, 1, 1, 8)      1544        block2b_se_reshape[1][0]
# __________________________________________________________________________________________________
# block2b_se_expand (Conv2D)      (None, 1, 1, 192)    1728        block2b_se_reduce[1][0]
# __________________________________________________________________________________________________
# block2b_se_excite (Multiply)    (None, None, None, 1 0           block2b_activation[1][0]
#                                                                  block2b_se_expand[1][0]
# __________________________________________________________________________________________________
# block2b_project_conv (Conv2D)   (None, None, None, 3 6144        block2b_se_excite[1][0]
# __________________________________________________________________________________________________
# block2b_project_bn (BatchNormal (None, None, None, 3 128         block2b_project_conv[1][0]
# __________________________________________________________________________________________________
# block2b_drop (FixedDropout)     (None, None, None, 3 0           block2b_project_bn[1][0]
# __________________________________________________________________________________________________
# block2b_add (Add)               (None, None, None, 3 0           block2b_drop[1][0]
#                                                                  block2a_project_bn[1][0]
# __________________________________________________________________________________________________
# block2c_expand_conv (Conv2D)    (None, None, None, 1 6144        block2b_add[1][0]
# __________________________________________________________________________________________________
# block2c_expand_bn (BatchNormali (None, None, None, 1 768         block2c_expand_conv[1][0]
# __________________________________________________________________________________________________
# block2c_expand_activation (Acti (None, None, None, 1 0           block2c_expand_bn[1][0]
# __________________________________________________________________________________________________
# block2c_dwconv (DepthwiseConv2D (None, None, None, 1 1728        block2c_expand_activation[1][0]
# __________________________________________________________________________________________________
# block2c_bn (BatchNormalization) (None, None, None, 1 768         block2c_dwconv[1][0]
# __________________________________________________________________________________________________
# block2c_activation (Activation) (None, None, None, 1 0           block2c_bn[1][0]
# __________________________________________________________________________________________________
# block2c_se_squeeze (GlobalAvera (None, 192)          0           block2c_activation[1][0]
# __________________________________________________________________________________________________
# block2c_se_reshape (Reshape)    (None, 1, 1, 192)    0           block2c_se_squeeze[1][0]
# __________________________________________________________________________________________________
# block2c_se_reduce (Conv2D)      (None, 1, 1, 8)      1544        block2c_se_reshape[1][0]
# __________________________________________________________________________________________________
# block2c_se_expand (Conv2D)      (None, 1, 1, 192)    1728        block2c_se_reduce[1][0]
# __________________________________________________________________________________________________
# block2c_se_excite (Multiply)    (None, None, None, 1 0           block2c_activation[1][0]
#                                                                  block2c_se_expand[1][0]
# __________________________________________________________________________________________________
# block2c_project_conv (Conv2D)   (None, None, None, 3 6144        block2c_se_excite[1][0]
# __________________________________________________________________________________________________
# block2c_project_bn (BatchNormal (None, None, None, 3 128         block2c_project_conv[1][0]
# __________________________________________________________________________________________________
# block2c_drop (FixedDropout)     (None, None, None, 3 0           block2c_project_bn[1][0]
# __________________________________________________________________________________________________
# block2c_add (Add)               (None, None, None, 3 0           block2c_drop[1][0]
#                                                                  block2b_add[1][0]
# __________________________________________________________________________________________________
# block3a_expand_conv (Conv2D)    (None, None, None, 1 6144        block2c_add[1][0]
# __________________________________________________________________________________________________
# block3a_expand_bn (BatchNormali (None, None, None, 1 768         block3a_expand_conv[1][0]
# __________________________________________________________________________________________________
# block3a_expand_activation (Acti (None, None, None, 1 0           block3a_expand_bn[1][0]
# __________________________________________________________________________________________________
# block3a_dwconv (DepthwiseConv2D (None, None, None, 1 4800        block3a_expand_activation[1][0]
# __________________________________________________________________________________________________
# block3a_bn (BatchNormalization) (None, None, None, 1 768         block3a_dwconv[1][0]
# __________________________________________________________________________________________________
# block3a_activation (Activation) (None, None, None, 1 0           block3a_bn[1][0]
# __________________________________________________________________________________________________
# block3a_se_squeeze (GlobalAvera (None, 192)          0           block3a_activation[1][0]
# __________________________________________________________________________________________________
# block3a_se_reshape (Reshape)    (None, 1, 1, 192)    0           block3a_se_squeeze[1][0]
# __________________________________________________________________________________________________
# block3a_se_reduce (Conv2D)      (None, 1, 1, 8)      1544        block3a_se_reshape[1][0]
# __________________________________________________________________________________________________
# block3a_se_expand (Conv2D)      (None, 1, 1, 192)    1728        block3a_se_reduce[1][0]
# __________________________________________________________________________________________________
# block3a_se_excite (Multiply)    (None, None, None, 1 0           block3a_activation[1][0]
#                                                                  block3a_se_expand[1][0]
# __________________________________________________________________________________________________
# block3a_project_conv (Conv2D)   (None, None, None, 4 9216        block3a_se_excite[1][0]
# __________________________________________________________________________________________________
# block3a_project_bn (BatchNormal (None, None, None, 4 192         block3a_project_conv[1][0]
# __________________________________________________________________________________________________
# block3b_expand_conv (Conv2D)    (None, None, None, 2 13824       block3a_project_bn[1][0]
# __________________________________________________________________________________________________
# block3b_expand_bn (BatchNormali (None, None, None, 2 1152        block3b_expand_conv[1][0]
# __________________________________________________________________________________________________
# block3b_expand_activation (Acti (None, None, None, 2 0           block3b_expand_bn[1][0]
# __________________________________________________________________________________________________
# block3b_dwconv (DepthwiseConv2D (None, None, None, 2 7200        block3b_expand_activation[1][0]
# __________________________________________________________________________________________________
# block3b_bn (BatchNormalization) (None, None, None, 2 1152        block3b_dwconv[1][0]
# __________________________________________________________________________________________________
# block3b_activation (Activation) (None, None, None, 2 0           block3b_bn[1][0]
# __________________________________________________________________________________________________
# block3b_se_squeeze (GlobalAvera (None, 288)          0           block3b_activation[1][0]
# __________________________________________________________________________________________________
# block3b_se_reshape (Reshape)    (None, 1, 1, 288)    0           block3b_se_squeeze[1][0]
# __________________________________________________________________________________________________
# block3b_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block3b_se_reshape[1][0]
# __________________________________________________________________________________________________
# block3b_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block3b_se_reduce[1][0]
# __________________________________________________________________________________________________
# block3b_se_excite (Multiply)    (None, None, None, 2 0           block3b_activation[1][0]
#                                                                  block3b_se_expand[1][0]
# __________________________________________________________________________________________________
# block3b_project_conv (Conv2D)   (None, None, None, 4 13824       block3b_se_excite[1][0]
# __________________________________________________________________________________________________
# block3b_project_bn (BatchNormal (None, None, None, 4 192         block3b_project_conv[1][0]
# __________________________________________________________________________________________________
# block3b_drop (FixedDropout)     (None, None, None, 4 0           block3b_project_bn[1][0]
# __________________________________________________________________________________________________
# block3b_add (Add)               (None, None, None, 4 0           block3b_drop[1][0]
#                                                                  block3a_project_bn[1][0]
# __________________________________________________________________________________________________
# block3c_expand_conv (Conv2D)    (None, None, None, 2 13824       block3b_add[1][0]
# __________________________________________________________________________________________________
# block3c_expand_bn (BatchNormali (None, None, None, 2 1152        block3c_expand_conv[1][0]
# __________________________________________________________________________________________________
# block3c_expand_activation (Acti (None, None, None, 2 0           block3c_expand_bn[1][0]
# __________________________________________________________________________________________________
# block3c_dwconv (DepthwiseConv2D (None, None, None, 2 7200        block3c_expand_activation[1][0]
# __________________________________________________________________________________________________
# block3c_bn (BatchNormalization) (None, None, None, 2 1152        block3c_dwconv[1][0]
# __________________________________________________________________________________________________
# block3c_activation (Activation) (None, None, None, 2 0           block3c_bn[1][0]
# __________________________________________________________________________________________________
# block3c_se_squeeze (GlobalAvera (None, 288)          0           block3c_activation[1][0]
# __________________________________________________________________________________________________
# block3c_se_reshape (Reshape)    (None, 1, 1, 288)    0           block3c_se_squeeze[1][0]
# __________________________________________________________________________________________________
# block3c_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block3c_se_reshape[1][0]
# __________________________________________________________________________________________________
# block3c_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block3c_se_reduce[1][0]
# __________________________________________________________________________________________________
# block3c_se_excite (Multiply)    (None, None, None, 2 0           block3c_activation[1][0]
#                                                                  block3c_se_expand[1][0]
# __________________________________________________________________________________________________
# block3c_project_conv (Conv2D)   (None, None, None, 4 13824       block3c_se_excite[1][0]
# __________________________________________________________________________________________________
# block3c_project_bn (BatchNormal (None, None, None, 4 192         block3c_project_conv[1][0]
# __________________________________________________________________________________________________
# block3c_drop (FixedDropout)     (None, None, None, 4 0           block3c_project_bn[1][0]
# __________________________________________________________________________________________________
# block3c_add (Add)               (None, None, None, 4 0           block3c_drop[1][0]
#                                                                  block3b_add[1][0]
# __________________________________________________________________________________________________
# block4a_expand_conv (Conv2D)    (None, None, None, 2 13824       block3c_add[1][0]
# __________________________________________________________________________________________________
# block4a_expand_bn (BatchNormali (None, None, None, 2 1152        block4a_expand_conv[1][0]
# __________________________________________________________________________________________________
# block4a_expand_activation (Acti (None, None, None, 2 0           block4a_expand_bn[1][0]
# __________________________________________________________________________________________________
# block4a_dwconv (DepthwiseConv2D (None, None, None, 2 2592        block4a_expand_activation[1][0]
# __________________________________________________________________________________________________
# block4a_bn (BatchNormalization) (None, None, None, 2 1152        block4a_dwconv[1][0]
# __________________________________________________________________________________________________
# block4a_activation (Activation) (None, None, None, 2 0           block4a_bn[1][0]
# __________________________________________________________________________________________________
# block4a_se_squeeze (GlobalAvera (None, 288)          0           block4a_activation[1][0]
# __________________________________________________________________________________________________
# block4a_se_reshape (Reshape)    (None, 1, 1, 288)    0           block4a_se_squeeze[1][0]
# __________________________________________________________________________________________________
# block4a_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block4a_se_reshape[1][0]
# __________________________________________________________________________________________________
# block4a_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block4a_se_reduce[1][0]
# __________________________________________________________________________________________________
# block4a_se_excite (Multiply)    (None, None, None, 2 0           block4a_activation[1][0]
#                                                                  block4a_se_expand[1][0]
# __________________________________________________________________________________________________
# block4a_project_conv (Conv2D)   (None, None, None, 9 27648       block4a_se_excite[1][0]
# __________________________________________________________________________________________________
# block4a_project_bn (BatchNormal (None, None, None, 9 384         block4a_project_conv[1][0]
# __________________________________________________________________________________________________
# block4b_expand_conv (Conv2D)    (None, None, None, 5 55296       block4a_project_bn[1][0]
# __________________________________________________________________________________________________
# block4b_expand_bn (BatchNormali (None, None, None, 5 2304        block4b_expand_conv[1][0]
# __________________________________________________________________________________________________
# block4b_expand_activation (Acti (None, None, None, 5 0           block4b_expand_bn[1][0]
# __________________________________________________________________________________________________
# block4b_dwconv (DepthwiseConv2D (None, None, None, 5 5184        block4b_expand_activation[1][0]
# __________________________________________________________________________________________________
# block4b_bn (BatchNormalization) (None, None, None, 5 2304        block4b_dwconv[1][0]
# __________________________________________________________________________________________________
# block4b_activation (Activation) (None, None, None, 5 0           block4b_bn[1][0]
# __________________________________________________________________________________________________
# block4b_se_squeeze (GlobalAvera (None, 576)          0           block4b_activation[1][0]
# __________________________________________________________________________________________________
# block4b_se_reshape (Reshape)    (None, 1, 1, 576)    0           block4b_se_squeeze[1][0]
# __________________________________________________________________________________________________
# block4b_se_reduce (Conv2D)      (None, 1, 1, 24)     13848       block4b_se_reshape[1][0]
# __________________________________________________________________________________________________
# block4b_se_expand (Conv2D)      (None, 1, 1, 576)    14400       block4b_se_reduce[1][0]
# __________________________________________________________________________________________________
# block4b_se_excite (Multiply)    (None, None, None, 5 0           block4b_activation[1][0]
#                                                                  block4b_se_expand[1][0]
# __________________________________________________________________________________________________
# block4b_project_conv (Conv2D)   (None, None, None, 9 55296       block4b_se_excite[1][0]
# __________________________________________________________________________________________________
# block4b_project_bn (BatchNormal (None, None, None, 9 384         block4b_project_conv[1][0]
# __________________________________________________________________________________________________
# block4b_drop (FixedDropout)     (None, None, None, 9 0           block4b_project_bn[1][0]
# __________________________________________________________________________________________________
# block4b_add (Add)               (None, None, None, 9 0           block4b_drop[1][0]
#                                                                  block4a_project_bn[1][0]
# __________________________________________________________________________________________________
# block4c_expand_conv (Conv2D)    (None, None, None, 5 55296       block4b_add[1][0]
# __________________________________________________________________________________________________
# block4c_expand_bn (BatchNormali (None, None, None, 5 2304        block4c_expand_conv[1][0]
# __________________________________________________________________________________________________
# block4c_expand_activation (Acti (None, None, None, 5 0           block4c_expand_bn[1][0]
# __________________________________________________________________________________________________
# block4c_dwconv (DepthwiseConv2D (None, None, None, 5 5184        block4c_expand_activation[1][0]
# __________________________________________________________________________________________________
# block4c_bn (BatchNormalization) (None, None, None, 5 2304        block4c_dwconv[1][0]
# __________________________________________________________________________________________________
# block4c_activation (Activation) (None, None, None, 5 0           block4c_bn[1][0]
# __________________________________________________________________________________________________
# block4c_se_squeeze (GlobalAvera (None, 576)          0           block4c_activation[1][0]
# __________________________________________________________________________________________________
# block4c_se_reshape (Reshape)    (None, 1, 1, 576)    0           block4c_se_squeeze[1][0]
# __________________________________________________________________________________________________
# block4c_se_reduce (Conv2D)      (None, 1, 1, 24)     13848       block4c_se_reshape[1][0]
# __________________________________________________________________________________________________
# block4c_se_expand (Conv2D)      (None, 1, 1, 576)    14400       block4c_se_reduce[1][0]
# __________________________________________________________________________________________________
# block4c_se_excite (Multiply)    (None, None, None, 5 0           block4c_activation[1][0]
#                                                                  block4c_se_expand[1][0]
# __________________________________________________________________________________________________
# block4c_project_conv (Conv2D)   (None, None, None, 9 55296       block4c_se_excite[1][0]
# __________________________________________________________________________________________________
# block4c_project_bn (BatchNormal (None, None, None, 9 384         block4c_project_conv[1][0]
# __________________________________________________________________________________________________
# block4c_drop (FixedDropout)     (None, None, None, 9 0           block4c_project_bn[1][0]
# __________________________________________________________________________________________________
# block4c_add (Add)               (None, None, None, 9 0           block4c_drop[1][0]
#                                                                  block4b_add[1][0]
# __________________________________________________________________________________________________
# block4d_expand_conv (Conv2D)    (None, None, None, 5 55296       block4c_add[1][0]
# __________________________________________________________________________________________________
# block4d_expand_bn (BatchNormali (None, None, None, 5 2304        block4d_expand_conv[1][0]
# __________________________________________________________________________________________________
# block4d_expand_activation (Acti (None, None, None, 5 0           block4d_expand_bn[1][0]
# __________________________________________________________________________________________________
# block4d_dwconv (DepthwiseConv2D (None, None, None, 5 5184        block4d_expand_activation[1][0]
# __________________________________________________________________________________________________
# block4d_bn (BatchNormalization) (None, None, None, 5 2304        block4d_dwconv[1][0]
# __________________________________________________________________________________________________
# block4d_activation (Activation) (None, None, None, 5 0           block4d_bn[1][0]
# __________________________________________________________________________________________________
# block4d_se_squeeze (GlobalAvera (None, 576)          0           block4d_activation[1][0]
# __________________________________________________________________________________________________
# block4d_se_reshape (Reshape)    (None, 1, 1, 576)    0           block4d_se_squeeze[1][0]
# __________________________________________________________________________________________________
# block4d_se_reduce (Conv2D)      (None, 1, 1, 24)     13848       block4d_se_reshape[1][0]
# __________________________________________________________________________________________________
# block4d_se_expand (Conv2D)      (None, 1, 1, 576)    14400       block4d_se_reduce[1][0]
# __________________________________________________________________________________________________
# block4d_se_excite (Multiply)    (None, None, None, 5 0           block4d_activation[1][0]
#                                                                  block4d_se_expand[1][0]
# __________________________________________________________________________________________________
# block4d_project_conv (Conv2D)   (None, None, None, 9 55296       block4d_se_excite[1][0]
# __________________________________________________________________________________________________
# block4d_project_bn (BatchNormal (None, None, None, 9 384         block4d_project_conv[1][0]
# __________________________________________________________________________________________________
# block4d_drop (FixedDropout)     (None, None, None, 9 0           block4d_project_bn[1][0]
# __________________________________________________________________________________________________
# block4d_add (Add)               (None, None, None, 9 0           block4d_drop[1][0]
#                                                                  block4c_add[1][0]
# __________________________________________________________________________________________________
# block4e_expand_conv (Conv2D)    (None, None, None, 5 55296       block4d_add[1][0]
# __________________________________________________________________________________________________
# block4e_expand_bn (BatchNormali (None, None, None, 5 2304        block4e_expand_conv[1][0]
# __________________________________________________________________________________________________
# block4e_expand_activation (Acti (None, None, None, 5 0           block4e_expand_bn[1][0]
# __________________________________________________________________________________________________
# block4e_dwconv (DepthwiseConv2D (None, None, None, 5 5184        block4e_expand_activation[1][0]
# __________________________________________________________________________________________________
# block4e_bn (BatchNormalization) (None, None, None, 5 2304        block4e_dwconv[1][0]
# __________________________________________________________________________________________________
# block4e_activation (Activation) (None, None, None, 5 0           block4e_bn[1][0]
# __________________________________________________________________________________________________
# block4e_se_squeeze (GlobalAvera (None, 576)          0           block4e_activation[1][0]
# __________________________________________________________________________________________________
# block4e_se_reshape (Reshape)    (None, 1, 1, 576)    0           block4e_se_squeeze[1][0]
# __________________________________________________________________________________________________
# block4e_se_reduce (Conv2D)      (None, 1, 1, 24)     13848       block4e_se_reshape[1][0]
# __________________________________________________________________________________________________
# block4e_se_expand (Conv2D)      (None, 1, 1, 576)    14400       block4e_se_reduce[1][0]
# __________________________________________________________________________________________________
# block4e_se_excite (Multiply)    (None, None, None, 5 0           block4e_activation[1][0]
#                                                                  block4e_se_expand[1][0]
# __________________________________________________________________________________________________
# block4e_project_conv (Conv2D)   (None, None, None, 9 55296       block4e_se_excite[1][0]
# __________________________________________________________________________________________________
# block4e_project_bn (BatchNormal (None, None, None, 9 384         block4e_project_conv[1][0]
# __________________________________________________________________________________________________
# block4e_drop (FixedDropout)     (None, None, None, 9 0           block4e_project_bn[1][0]
# __________________________________________________________________________________________________
# block4e_add (Add)               (None, None, None, 9 0           block4e_drop[1][0]
#                                                                  block4d_add[1][0]
# __________________________________________________________________________________________________
# block5a_expand_conv (Conv2D)    (None, None, None, 5 55296       block4e_add[1][0]
# __________________________________________________________________________________________________
# block5a_expand_bn (BatchNormali (None, None, None, 5 2304        block5a_expand_conv[1][0]
# __________________________________________________________________________________________________
# block5a_expand_activation (Acti (None, None, None, 5 0           block5a_expand_bn[1][0]
# __________________________________________________________________________________________________
# block5a_dwconv (DepthwiseConv2D (None, None, None, 5 14400       block5a_expand_activation[1][0]
# __________________________________________________________________________________________________
# block5a_bn (BatchNormalization) (None, None, None, 5 2304        block5a_dwconv[1][0]
# __________________________________________________________________________________________________
# block5a_activation (Activation) (None, None, None, 5 0           block5a_bn[1][0]
# __________________________________________________________________________________________________
# block5a_se_squeeze (GlobalAvera (None, 576)          0           block5a_activation[1][0]
# __________________________________________________________________________________________________
# block5a_se_reshape (Reshape)    (None, 1, 1, 576)    0           block5a_se_squeeze[1][0]
# __________________________________________________________________________________________________
# block5a_se_reduce (Conv2D)      (None, 1, 1, 24)     13848       block5a_se_reshape[1][0]
# __________________________________________________________________________________________________
# block5a_se_expand (Conv2D)      (None, 1, 1, 576)    14400       block5a_se_reduce[1][0]
# __________________________________________________________________________________________________
# block5a_se_excite (Multiply)    (None, None, None, 5 0           block5a_activation[1][0]
#                                                                  block5a_se_expand[1][0]
# __________________________________________________________________________________________________
# block5a_project_conv (Conv2D)   (None, None, None, 1 78336       block5a_se_excite[1][0]
# __________________________________________________________________________________________________
# block5a_project_bn (BatchNormal (None, None, None, 1 544         block5a_project_conv[1][0]
# __________________________________________________________________________________________________
# block5b_expand_conv (Conv2D)    (None, None, None, 8 110976      block5a_project_bn[1][0]
# __________________________________________________________________________________________________
# block5b_expand_bn (BatchNormali (None, None, None, 8 3264        block5b_expand_conv[1][0]
# __________________________________________________________________________________________________
# block5b_expand_activation (Acti (None, None, None, 8 0           block5b_expand_bn[1][0]
# __________________________________________________________________________________________________
# block5b_dwconv (DepthwiseConv2D (None, None, None, 8 20400       block5b_expand_activation[1][0]
# __________________________________________________________________________________________________
# block5b_bn (BatchNormalization) (None, None, None, 8 3264        block5b_dwconv[1][0]
# __________________________________________________________________________________________________
# block5b_activation (Activation) (None, None, None, 8 0           block5b_bn[1][0]
# __________________________________________________________________________________________________
# block5b_se_squeeze (GlobalAvera (None, 816)          0           block5b_activation[1][0]
# __________________________________________________________________________________________________
# block5b_se_reshape (Reshape)    (None, 1, 1, 816)    0           block5b_se_squeeze[1][0]
# __________________________________________________________________________________________________
# block5b_se_reduce (Conv2D)      (None, 1, 1, 34)     27778       block5b_se_reshape[1][0]
# __________________________________________________________________________________________________
# block5b_se_expand (Conv2D)      (None, 1, 1, 816)    28560       block5b_se_reduce[1][0]
# __________________________________________________________________________________________________
# block5b_se_excite (Multiply)    (None, None, None, 8 0           block5b_activation[1][0]
#                                                                  block5b_se_expand[1][0]
# __________________________________________________________________________________________________
# block5b_project_conv (Conv2D)   (None, None, None, 1 110976      block5b_se_excite[1][0]
# __________________________________________________________________________________________________
# block5b_project_bn (BatchNormal (None, None, None, 1 544         block5b_project_conv[1][0]
# __________________________________________________________________________________________________
# block5b_drop (FixedDropout)     (None, None, None, 1 0           block5b_project_bn[1][0]
# __________________________________________________________________________________________________
# block5b_add (Add)               (None, None, None, 1 0           block5b_drop[1][0]
#                                                                  block5a_project_bn[1][0]
# __________________________________________________________________________________________________
# block5c_expand_conv (Conv2D)    (None, None, None, 8 110976      block5b_add[1][0]
# __________________________________________________________________________________________________
# block5c_expand_bn (BatchNormali (None, None, None, 8 3264        block5c_expand_conv[1][0]
# __________________________________________________________________________________________________
# block5c_expand_activation (Acti (None, None, None, 8 0           block5c_expand_bn[1][0]
# __________________________________________________________________________________________________
# block5c_dwconv (DepthwiseConv2D (None, None, None, 8 20400       block5c_expand_activation[1][0]
# __________________________________________________________________________________________________
# block5c_bn (BatchNormalization) (None, None, None, 8 3264        block5c_dwconv[1][0]
# __________________________________________________________________________________________________
# block5c_activation (Activation) (None, None, None, 8 0           block5c_bn[1][0]
# __________________________________________________________________________________________________
# block5c_se_squeeze (GlobalAvera (None, 816)          0           block5c_activation[1][0]
# __________________________________________________________________________________________________
# block5c_se_reshape (Reshape)    (None, 1, 1, 816)    0           block5c_se_squeeze[1][0]
# __________________________________________________________________________________________________
# block5c_se_reduce (Conv2D)      (None, 1, 1, 34)     27778       block5c_se_reshape[1][0]
# __________________________________________________________________________________________________
# block5c_se_expand (Conv2D)      (None, 1, 1, 816)    28560       block5c_se_reduce[1][0]
# __________________________________________________________________________________________________
# block5c_se_excite (Multiply)    (None, None, None, 8 0           block5c_activation[1][0]
#                                                                  block5c_se_expand[1][0]
# __________________________________________________________________________________________________
# block5c_project_conv (Conv2D)   (None, None, None, 1 110976      block5c_se_excite[1][0]
# __________________________________________________________________________________________________
# block5c_project_bn (BatchNormal (None, None, None, 1 544         block5c_project_conv[1][0]
# __________________________________________________________________________________________________
# block5c_drop (FixedDropout)     (None, None, None, 1 0           block5c_project_bn[1][0]
# __________________________________________________________________________________________________
# block5c_add (Add)               (None, None, None, 1 0           block5c_drop[1][0]
# ...
# __________________________________________________________________________________________________
# block6f_project_bn (BatchNormal (None, None, None, 2 928         block6f_project_conv[1][0]
# __________________________________________________________________________________________________
# block6f_drop (FixedDropout)     (None, None, None, 2 0           block6f_project_bn[1][0]
# __________________________________________________________________________________________________
# block6f_add (Add)               (None, None, None, 2 0           block6f_drop[1][0]
#                                                                  block6e_add[1][0]
# __________________________________________________________________________________________________
# block7a_expand_conv (Conv2D)    (None, None, None, 1 322944      block6f_add[1][0]
# __________________________________________________________________________________________________
# block7a_expand_bn (BatchNormali (None, None, None, 1 5568        block7a_expand_conv[1][0]
# __________________________________________________________________________________________________
# block7a_expand_activation (Acti (None, None, None, 1 0           block7a_expand_bn[1][0]
# __________________________________________________________________________________________________
# block7a_dwconv (DepthwiseConv2D (None, None, None, 1 12528       block7a_expand_activation[1][0]
# __________________________________________________________________________________________________
# block7a_bn (BatchNormalization) (None, None, None, 1 5568        block7a_dwconv[1][0]
# __________________________________________________________________________________________________
# block7a_activation (Activation) (None, None, None, 1 0           block7a_bn[1][0]
# __________________________________________________________________________________________________
# block7a_se_squeeze (GlobalAvera (None, 1392)         0           block7a_activation[1][0]
# __________________________________________________________________________________________________
# block7a_se_reshape (Reshape)    (None, 1, 1, 1392)   0           block7a_se_squeeze[1][0]
# __________________________________________________________________________________________________
# block7a_se_reduce (Conv2D)      (None, 1, 1, 58)     80794       block7a_se_reshape[1][0]
# __________________________________________________________________________________________________
# block7a_se_expand (Conv2D)      (None, 1, 1, 1392)   82128       block7a_se_reduce[1][0]
# __________________________________________________________________________________________________
# block7a_se_excite (Multiply)    (None, None, None, 1 0           block7a_activation[1][0]
#                                                                  block7a_se_expand[1][0]
# __________________________________________________________________________________________________
# block7a_project_conv (Conv2D)   (None, None, None, 3 534528      block7a_se_excite[1][0]
# __________________________________________________________________________________________________
# block7a_project_bn (BatchNormal (None, None, None, 3 1536        block7a_project_conv[1][0]
# __________________________________________________________________________________________________
# block7b_expand_conv (Conv2D)    (None, None, None, 2 884736      block7a_project_bn[1][0]
# __________________________________________________________________________________________________
# block7b_expand_bn (BatchNormali (None, None, None, 2 9216        block7b_expand_conv[1][0]
# __________________________________________________________________________________________________
# block7b_expand_activation (Acti (None, None, None, 2 0           block7b_expand_bn[1][0]
# __________________________________________________________________________________________________
# block7b_dwconv (DepthwiseConv2D (None, None, None, 2 20736       block7b_expand_activation[1][0]
# __________________________________________________________________________________________________
# block7b_bn (BatchNormalization) (None, None, None, 2 9216        block7b_dwconv[1][0]
# __________________________________________________________________________________________________
# block7b_activation (Activation) (None, None, None, 2 0           block7b_bn[1][0]
# __________________________________________________________________________________________________
# block7b_se_squeeze (GlobalAvera (None, 2304)         0           block7b_activation[1][0]
# __________________________________________________________________________________________________
# block7b_se_reshape (Reshape)    (None, 1, 1, 2304)   0           block7b_se_squeeze[1][0]
# __________________________________________________________________________________________________
# block7b_se_reduce (Conv2D)      (None, 1, 1, 96)     221280      block7b_se_reshape[1][0]
# __________________________________________________________________________________________________
# block7b_se_expand (Conv2D)      (None, 1, 1, 2304)   223488      block7b_se_reduce[1][0]
# __________________________________________________________________________________________________
# block7b_se_excite (Multiply)    (None, None, None, 2 0           block7b_activation[1][0]
#                                                                  block7b_se_expand[1][0]
# __________________________________________________________________________________________________
# block7b_project_conv (Conv2D)   (None, None, None, 3 884736      block7b_se_excite[1][0]
# __________________________________________________________________________________________________
# block7b_project_bn (BatchNormal (None, None, None, 3 1536        block7b_project_conv[1][0]
# __________________________________________________________________________________________________
# block7b_drop (FixedDropout)     (None, None, None, 3 0           block7b_project_bn[1][0]
# __________________________________________________________________________________________________
# block7b_add (Add)               (None, None, None, 3 0           block7b_drop[1][0]
#                                                                  block7a_project_bn[1][0]
# __________________________________________________________________________________________________
# top_conv (Conv2D)               (None, None, None, 1 589824      block7b_add[1][0]
# __________________________________________________________________________________________________
# top_bn (BatchNormalization)     (None, None, None, 1 6144        top_conv[1][0]
# __________________________________________________________________________________________________
# top_activation (Activation)     (None, None, None, 1 0           top_bn[1][0]
# __________________________________________________________________________________________________
# decoder_stage0_upsampling (UpSa (None, None, None, 1 0           top_activation[1][0]
# __________________________________________________________________________________________________
# decoder_stage0_concat (Concaten (None, None, None, 2 0           decoder_stage0_upsampling[1][0]
#                                                                  block6a_expand_activation[1][0]
# __________________________________________________________________________________________________
# decoder_stage0a_conv (Conv2D)   (None, None, None, 2 5419008     decoder_stage0_concat[1][0]
# __________________________________________________________________________________________________
# decoder_stage0a_bn (BatchNormal (None, None, None, 2 1024        decoder_stage0a_conv[1][0]
# __________________________________________________________________________________________________
# decoder_stage0a_relu (Activatio (None, None, None, 2 0           decoder_stage0a_bn[1][0]
# __________________________________________________________________________________________________
# decoder_stage0b_conv (Conv2D)   (None, None, None, 2 589824      decoder_stage0a_relu[1][0]
# __________________________________________________________________________________________________
# decoder_stage0b_bn (BatchNormal (None, None, None, 2 1024        decoder_stage0b_conv[1][0]
# __________________________________________________________________________________________________
# decoder_stage0b_relu (Activatio (None, None, None, 2 0           decoder_stage0b_bn[1][0]
# __________________________________________________________________________________________________
# decoder_stage1_upsampling (UpSa (None, None, None, 2 0           decoder_stage0b_relu[1][0]
# __________________________________________________________________________________________________
# decoder_stage1_concat (Concaten (None, None, None, 5 0           decoder_stage1_upsampling[1][0]
#                                                                  block4a_expand_activation[1][0]
# __________________________________________________________________________________________________
# decoder_stage1a_conv (Conv2D)   (None, None, None, 1 626688      decoder_stage1_concat[1][0]
# __________________________________________________________________________________________________
# decoder_stage1a_bn (BatchNormal (None, None, None, 1 512         decoder_stage1a_conv[1][0]
# __________________________________________________________________________________________________
# decoder_stage1a_relu (Activatio (None, None, None, 1 0           decoder_stage1a_bn[1][0]
# __________________________________________________________________________________________________
# decoder_stage1b_conv (Conv2D)   (None, None, None, 1 147456      decoder_stage1a_relu[1][0]
# __________________________________________________________________________________________________
# decoder_stage1b_bn (BatchNormal (None, None, None, 1 512         decoder_stage1b_conv[1][0]
# __________________________________________________________________________________________________
# decoder_stage1b_relu (Activatio (None, None, None, 1 0           decoder_stage1b_bn[1][0]
# __________________________________________________________________________________________________
# decoder_stage2_upsampling (UpSa (None, None, None, 1 0           decoder_stage1b_relu[1][0]
# __________________________________________________________________________________________________
# decoder_stage2_concat (Concaten (None, None, None, 3 0           decoder_stage2_upsampling[1][0]
#                                                                  block3a_expand_activation[1][0]
# __________________________________________________________________________________________________
# decoder_stage2a_conv (Conv2D)   (None, None, None, 6 184320      decoder_stage2_concat[1][0]
# __________________________________________________________________________________________________
# decoder_stage2a_bn (BatchNormal (None, None, None, 6 256         decoder_stage2a_conv[1][0]
# __________________________________________________________________________________________________
# decoder_stage2a_relu (Activatio (None, None, None, 6 0           decoder_stage2a_bn[1][0]
# __________________________________________________________________________________________________
# decoder_stage2b_conv (Conv2D)   (None, None, None, 6 36864       decoder_stage2a_relu[1][0]
# __________________________________________________________________________________________________
# decoder_stage2b_bn (BatchNormal (None, None, None, 6 256         decoder_stage2b_conv[1][0]
# __________________________________________________________________________________________________
# decoder_stage2b_relu (Activatio (None, None, None, 6 0           decoder_stage2b_bn[1][0]
# __________________________________________________________________________________________________
# decoder_stage3_upsampling (UpSa (None, None, None, 6 0           decoder_stage2b_relu[1][0]
# __________________________________________________________________________________________________
# decoder_stage3_concat (Concaten (None, None, None, 2 0           decoder_stage3_upsampling[1][0]
#                                                                  block2a_expand_activation[1][0]
# __________________________________________________________________________________________________
# decoder_stage3a_conv (Conv2D)   (None, None, None, 3 59904       decoder_stage3_concat[1][0]
# __________________________________________________________________________________________________
# decoder_stage3a_bn (BatchNormal (None, None, None, 3 128         decoder_stage3a_conv[1][0]
# __________________________________________________________________________________________________
# decoder_stage3a_relu (Activatio (None, None, None, 3 0           decoder_stage3a_bn[1][0]
# __________________________________________________________________________________________________
# decoder_stage3b_conv (Conv2D)   (None, None, None, 3 9216        decoder_stage3a_relu[1][0]
# __________________________________________________________________________________________________
# decoder_stage3b_bn (BatchNormal (None, None, None, 3 128         decoder_stage3b_conv[1][0]
# __________________________________________________________________________________________________
# decoder_stage3b_relu (Activatio (None, None, None, 3 0           decoder_stage3b_bn[1][0]
# __________________________________________________________________________________________________
# decoder_stage4_upsampling (UpSa (None, None, None, 3 0           decoder_stage3b_relu[1][0]
# __________________________________________________________________________________________________
# decoder_stage4a_conv (Conv2D)   (None, None, None, 1 4608        decoder_stage4_upsampling[1][0]
# __________________________________________________________________________________________________
# decoder_stage4a_bn (BatchNormal (None, None, None, 1 64          decoder_stage4a_conv[1][0]
# __________________________________________________________________________________________________
# decoder_stage4a_relu (Activatio (None, None, None, 1 0           decoder_stage4a_bn[1][0]
# __________________________________________________________________________________________________
# decoder_stage4b_conv (Conv2D)   (None, None, None, 1 2304        decoder_stage4a_relu[1][0]
# __________________________________________________________________________________________________
# decoder_stage4b_bn (BatchNormal (None, None, None, 1 64          decoder_stage4b_conv[1][0]
# __________________________________________________________________________________________________
# decoder_stage4b_relu (Activatio (None, None, None, 1 0           decoder_stage4b_bn[1][0]
# __________________________________________________________________________________________________
# final_conv (Conv2D)             (None, None, None, 1 145         decoder_stage4b_relu[1][0]
# __________________________________________________________________________________________________
# sigmoid (Activation)            (None, None, None, 1 0           final_conv[1][0]
# ==================================================================================================
# Total params: 17,867,833
# Trainable params: 17,778,553
# Non-trainable params: 89,280
# __________________________________________________________________________________________________

# %%
import numpy as np

for i, w in enumerate(model_for_export.get_weights()):
    print(
        "{} -- Total:{}, Zeros: {:.2f}%".format(
            model_for_export.weights[i].name, w.size, np.sum(w == 0) / w.size * 100
        )
    )
# Out:
# stem_conv_1/kernel:0 -- Total:1080, Zeros: 79.63%
# stem_bn_1/gamma:0 -- Total:40, Zeros: 0.00%
# stem_bn_1/beta:0 -- Total:40, Zeros: 0.00%
# stem_bn_1/moving_mean:0 -- Total:40, Zeros: 0.00%
# stem_bn_1/moving_variance:0 -- Total:40, Zeros: 0.00%
# block1a_dwconv_1/depthwise_kernel:0 -- Total:360, Zeros: 0.00%
# block1a_bn_1/gamma:0 -- Total:40, Zeros: 0.00%
# block1a_bn_1/beta:0 -- Total:40, Zeros: 0.00%
# block1a_bn_1/moving_mean:0 -- Total:40, Zeros: 0.00%
# block1a_bn_1/moving_variance:0 -- Total:40, Zeros: 0.00%
# block1a_se_reduce_1/kernel:0 -- Total:400, Zeros: 79.75%
# block1a_se_reduce_1/bias:0 -- Total:10, Zeros: 0.00%
# block1a_se_expand_1/kernel:0 -- Total:400, Zeros: 79.75%
# block1a_se_expand_1/bias:0 -- Total:40, Zeros: 0.00%
# block1a_project_conv_1/kernel:0 -- Total:960, Zeros: 79.58%
# block1a_project_bn_1/gamma:0 -- Total:24, Zeros: 0.00%
# block1a_project_bn_1/beta:0 -- Total:24, Zeros: 0.00%
# block1a_project_bn_1/moving_mean:0 -- Total:24, Zeros: 0.00%
# block1a_project_bn_1/moving_variance:0 -- Total:24, Zeros: 0.00%
# block1b_dwconv_1/depthwise_kernel:0 -- Total:216, Zeros: 0.00%
# block1b_bn_1/gamma:0 -- Total:24, Zeros: 0.00%
# block1b_bn_1/beta:0 -- Total:24, Zeros: 0.00%
# block1b_bn_1/moving_mean:0 -- Total:24, Zeros: 0.00%
# block1b_bn_1/moving_variance:0 -- Total:24, Zeros: 0.00%
# block1b_se_reduce_1/kernel:0 -- Total:144, Zeros: 79.86%
# block1b_se_reduce_1/bias:0 -- Total:6, Zeros: 0.00%
# block1b_se_expand_1/kernel:0 -- Total:144, Zeros: 79.86%
# block1b_se_expand_1/bias:0 -- Total:24, Zeros: 0.00%
# block1b_project_conv_1/kernel:0 -- Total:576, Zeros: 79.69%
# block1b_project_bn_1/gamma:0 -- Total:24, Zeros: 0.00%
# block1b_project_bn_1/beta:0 -- Total:24, Zeros: 0.00%
# block1b_project_bn_1/moving_mean:0 -- Total:24, Zeros: 0.00%
# block1b_project_bn_1/moving_variance:0 -- Total:24, Zeros: 0.00%
# block2a_expand_conv_1/kernel:0 -- Total:3456, Zeros: 79.63%
# block2a_expand_bn_1/gamma:0 -- Total:144, Zeros: 0.00%
# block2a_expand_bn_1/beta:0 -- Total:144, Zeros: 0.00%
# block2a_expand_bn_1/moving_mean:0 -- Total:144, Zeros: 0.00%
# block2a_expand_bn_1/moving_variance:0 -- Total:144, Zeros: 0.00%
# block2a_dwconv_1/depthwise_kernel:0 -- Total:1296, Zeros: 0.00%
# block2a_bn_1/gamma:0 -- Total:144, Zeros: 0.00%
# block2a_bn_1/beta:0 -- Total:144, Zeros: 0.00%
# block2a_bn_1/moving_mean:0 -- Total:144, Zeros: 0.00%
# block2a_bn_1/moving_variance:0 -- Total:144, Zeros: 0.00%
# block2a_se_reduce_1/kernel:0 -- Total:864, Zeros: 79.63%
# block2a_se_reduce_1/bias:0 -- Total:6, Zeros: 0.00%
# block2a_se_expand_1/kernel:0 -- Total:864, Zeros: 79.63%
# block2a_se_expand_1/bias:0 -- Total:144, Zeros: 0.00%
# block2a_project_conv_1/kernel:0 -- Total:4608, Zeros: 79.62%
# block2a_project_bn_1/gamma:0 -- Total:32, Zeros: 0.00%
# block2a_project_bn_1/beta:0 -- Total:32, Zeros: 0.00%
# block2a_project_bn_1/moving_mean:0 -- Total:32, Zeros: 0.00%
# block2a_project_bn_1/moving_variance:0 -- Total:32, Zeros: 0.00%
# block2b_expand_conv_1/kernel:0 -- Total:6144, Zeros: 79.64%
# block2b_expand_bn_1/gamma:0 -- Total:192, Zeros: 0.00%
# block2b_expand_bn_1/beta:0 -- Total:192, Zeros: 0.00%
# block2b_expand_bn_1/moving_mean:0 -- Total:192, Zeros: 0.00%
# block2b_expand_bn_1/moving_variance:0 -- Total:192, Zeros: 0.00%
# block2b_dwconv_1/depthwise_kernel:0 -- Total:1728, Zeros: 0.00%
# block2b_bn_1/gamma:0 -- Total:192, Zeros: 0.00%
# block2b_bn_1/beta:0 -- Total:192, Zeros: 0.00%
# block2b_bn_1/moving_mean:0 -- Total:192, Zeros: 0.00%
# block2b_bn_1/moving_variance:0 -- Total:192, Zeros: 0.00%
# block2b_se_reduce_1/kernel:0 -- Total:1536, Zeros: 79.62%
# block2b_se_reduce_1/bias:0 -- Total:8, Zeros: 0.00%
# block2b_se_expand_1/kernel:0 -- Total:1536, Zeros: 79.62%
# block2b_se_expand_1/bias:0 -- Total:192, Zeros: 0.00%
# block2b_project_conv_1/kernel:0 -- Total:6144, Zeros: 79.64%
# block2b_project_bn_1/gamma:0 -- Total:32, Zeros: 0.00%
# block2b_project_bn_1/beta:0 -- Total:32, Zeros: 0.00%
# block2b_project_bn_1/moving_mean:0 -- Total:32, Zeros: 0.00%
# block2b_project_bn_1/moving_variance:0 -- Total:32, Zeros: 0.00%
# block2c_expand_conv_1/kernel:0 -- Total:6144, Zeros: 79.64%
# block2c_expand_bn_1/gamma:0 -- Total:192, Zeros: 0.00%
# block2c_expand_bn_1/beta:0 -- Total:192, Zeros: 0.00%
# block2c_expand_bn_1/moving_mean:0 -- Total:192, Zeros: 0.00%
# block2c_expand_bn_1/moving_variance:0 -- Total:192, Zeros: 0.00%
# block2c_dwconv_1/depthwise_kernel:0 -- Total:1728, Zeros: 0.00%
# block2c_bn_1/gamma:0 -- Total:192, Zeros: 0.00%
# block2c_bn_1/beta:0 -- Total:192, Zeros: 0.00%
# block2c_bn_1/moving_mean:0 -- Total:192, Zeros: 0.00%
# block2c_bn_1/moving_variance:0 -- Total:192, Zeros: 0.00%
# block2c_se_reduce_1/kernel:0 -- Total:1536, Zeros: 79.62%
# block2c_se_reduce_1/bias:0 -- Total:8, Zeros: 0.00%
# block2c_se_expand_1/kernel:0 -- Total:1536, Zeros: 79.62%
# block2c_se_expand_1/bias:0 -- Total:192, Zeros: 0.00%
# block2c_project_conv_1/kernel:0 -- Total:6144, Zeros: 79.64%
# block2c_project_bn_1/gamma:0 -- Total:32, Zeros: 0.00%
# block2c_project_bn_1/beta:0 -- Total:32, Zeros: 0.00%
# block2c_project_bn_1/moving_mean:0 -- Total:32, Zeros: 0.00%
# block2c_project_bn_1/moving_variance:0 -- Total:32, Zeros: 0.00%
# block3a_expand_conv_1/kernel:0 -- Total:6144, Zeros: 79.64%
# block3a_expand_bn_1/gamma:0 -- Total:192, Zeros: 0.00%
# block3a_expand_bn_1/beta:0 -- Total:192, Zeros: 0.00%
# block3a_expand_bn_1/moving_mean:0 -- Total:192, Zeros: 0.00%
# block3a_expand_bn_1/moving_variance:0 -- Total:192, Zeros: 0.00%
# block3a_dwconv_1/depthwise_kernel:0 -- Total:4800, Zeros: 0.00%
# block3a_bn_1/gamma:0 -- Total:192, Zeros: 0.00%
# block3a_bn_1/beta:0 -- Total:192, Zeros: 0.00%
# block3a_bn_1/moving_mean:0 -- Total:192, Zeros: 0.00%
# block3a_bn_1/moving_variance:0 -- Total:192, Zeros: 0.00%
# block3a_se_reduce_1/kernel:0 -- Total:1536, Zeros: 79.62%
# block3a_se_reduce_1/bias:0 -- Total:8, Zeros: 0.00%
# block3a_se_expand_1/kernel:0 -- Total:1536, Zeros: 79.62%
# block3a_se_expand_1/bias:0 -- Total:192, Zeros: 0.00%
# block3a_project_conv_1/kernel:0 -- Total:9216, Zeros: 79.63%
# block3a_project_bn_1/gamma:0 -- Total:48, Zeros: 0.00%
# block3a_project_bn_1/beta:0 -- Total:48, Zeros: 0.00%
# block3a_project_bn_1/moving_mean:0 -- Total:48, Zeros: 0.00%
# block3a_project_bn_1/moving_variance:0 -- Total:48, Zeros: 0.00%
# block3b_expand_conv_1/kernel:0 -- Total:13824, Zeros: 79.63%
# block3b_expand_bn_1/gamma:0 -- Total:288, Zeros: 0.00%
# block3b_expand_bn_1/beta:0 -- Total:288, Zeros: 0.00%
# block3b_expand_bn_1/moving_mean:0 -- Total:288, Zeros: 0.00%
# block3b_expand_bn_1/moving_variance:0 -- Total:288, Zeros: 0.00%
# block3b_dwconv_1/depthwise_kernel:0 -- Total:7200, Zeros: 0.00%
# block3b_bn_1/gamma:0 -- Total:288, Zeros: 0.00%
# block3b_bn_1/beta:0 -- Total:288, Zeros: 0.00%
# block3b_bn_1/moving_mean:0 -- Total:288, Zeros: 0.00%
# block3b_bn_1/moving_variance:0 -- Total:288, Zeros: 0.00%
# block3b_se_reduce_1/kernel:0 -- Total:3456, Zeros: 79.63%
# block3b_se_reduce_1/bias:0 -- Total:12, Zeros: 0.00%
# block3b_se_expand_1/kernel:0 -- Total:3456, Zeros: 79.63%
# block3b_se_expand_1/bias:0 -- Total:288, Zeros: 0.00%
# block3b_project_conv_1/kernel:0 -- Total:13824, Zeros: 79.63%
# block3b_project_bn_1/gamma:0 -- Total:48, Zeros: 0.00%
# block3b_project_bn_1/beta:0 -- Total:48, Zeros: 0.00%
# block3b_project_bn_1/moving_mean:0 -- Total:48, Zeros: 0.00%
# block3b_project_bn_1/moving_variance:0 -- Total:48, Zeros: 0.00%
# block3c_expand_conv_1/kernel:0 -- Total:13824, Zeros: 79.63%
# block3c_expand_bn_1/gamma:0 -- Total:288, Zeros: 0.00%
# block3c_expand_bn_1/beta:0 -- Total:288, Zeros: 0.00%
# block3c_expand_bn_1/moving_mean:0 -- Total:288, Zeros: 0.00%
# block3c_expand_bn_1/moving_variance:0 -- Total:288, Zeros: 0.00%
# block3c_dwconv_1/depthwise_kernel:0 -- Total:7200, Zeros: 0.00%
# block3c_bn_1/gamma:0 -- Total:288, Zeros: 0.00%
# block3c_bn_1/beta:0 -- Total:288, Zeros: 0.00%
# block3c_bn_1/moving_mean:0 -- Total:288, Zeros: 0.00%
# block3c_bn_1/moving_variance:0 -- Total:288, Zeros: 0.00%
# block3c_se_reduce_1/kernel:0 -- Total:3456, Zeros: 79.63%
# block3c_se_reduce_1/bias:0 -- Total:12, Zeros: 0.00%
# block3c_se_expand_1/kernel:0 -- Total:3456, Zeros: 79.63%
# block3c_se_expand_1/bias:0 -- Total:288, Zeros: 0.00%
# block3c_project_conv_1/kernel:0 -- Total:13824, Zeros: 79.63%
# block3c_project_bn_1/gamma:0 -- Total:48, Zeros: 0.00%
# block3c_project_bn_1/beta:0 -- Total:48, Zeros: 0.00%
# block3c_project_bn_1/moving_mean:0 -- Total:48, Zeros: 0.00%
# block3c_project_bn_1/moving_variance:0 -- Total:48, Zeros: 0.00%
# block4a_expand_conv_1/kernel:0 -- Total:13824, Zeros: 79.63%
# block4a_expand_bn_1/gamma:0 -- Total:288, Zeros: 0.00%
# block4a_expand_bn_1/beta:0 -- Total:288, Zeros: 0.00%
# block4a_expand_bn_1/moving_mean:0 -- Total:288, Zeros: 0.00%
# block4a_expand_bn_1/moving_variance:0 -- Total:288, Zeros: 0.00%
# block4a_dwconv_1/depthwise_kernel:0 -- Total:2592, Zeros: 0.00%
# block4a_bn_1/gamma:0 -- Total:288, Zeros: 0.00%
# block4a_bn_1/beta:0 -- Total:288, Zeros: 0.00%
# block4a_bn_1/moving_mean:0 -- Total:288, Zeros: 0.00%
# block4a_bn_1/moving_variance:0 -- Total:288, Zeros: 0.00%
# block4a_se_reduce_1/kernel:0 -- Total:3456, Zeros: 79.63%
# block4a_se_reduce_1/bias:0 -- Total:12, Zeros: 0.00%
# block4a_se_expand_1/kernel:0 -- Total:3456, Zeros: 79.63%
# block4a_se_expand_1/bias:0 -- Total:288, Zeros: 0.00%
# block4a_project_conv_1/kernel:0 -- Total:27648, Zeros: 79.63%
# block4a_project_bn_1/gamma:0 -- Total:96, Zeros: 0.00%
# block4a_project_bn_1/beta:0 -- Total:96, Zeros: 0.00%
# block4a_project_bn_1/moving_mean:0 -- Total:96, Zeros: 0.00%
# block4a_project_bn_1/moving_variance:0 -- Total:96, Zeros: 0.00%
# block4b_expand_conv_1/kernel:0 -- Total:55296, Zeros: 79.63%
# block4b_expand_bn_1/gamma:0 -- Total:576, Zeros: 0.00%
# block4b_expand_bn_1/beta:0 -- Total:576, Zeros: 0.00%
# block4b_expand_bn_1/moving_mean:0 -- Total:576, Zeros: 0.00%
# block4b_expand_bn_1/moving_variance:0 -- Total:576, Zeros: 0.00%
# block4b_dwconv_1/depthwise_kernel:0 -- Total:5184, Zeros: 0.00%
# block4b_bn_1/gamma:0 -- Total:576, Zeros: 0.00%
# block4b_bn_1/beta:0 -- Total:576, Zeros: 0.00%
# block4b_bn_1/moving_mean:0 -- Total:576, Zeros: 0.00%
# block4b_bn_1/moving_variance:0 -- Total:576, Zeros: 0.00%
# block4b_se_reduce_1/kernel:0 -- Total:13824, Zeros: 79.63%
# block4b_se_reduce_1/bias:0 -- Total:24, Zeros: 0.00%
# block4b_se_expand_1/kernel:0 -- Total:13824, Zeros: 79.63%
# block4b_se_expand_1/bias:0 -- Total:576, Zeros: 0.00%
# block4b_project_conv_1/kernel:0 -- Total:55296, Zeros: 79.63%
# block4b_project_bn_1/gamma:0 -- Total:96, Zeros: 0.00%
# block4b_project_bn_1/beta:0 -- Total:96, Zeros: 0.00%
# block4b_project_bn_1/moving_mean:0 -- Total:96, Zeros: 0.00%
# block4b_project_bn_1/moving_variance:0 -- Total:96, Zeros: 0.00%
# block4c_expand_conv_1/kernel:0 -- Total:55296, Zeros: 79.63%
# block4c_expand_bn_1/gamma:0 -- Total:576, Zeros: 0.00%
# block4c_expand_bn_1/beta:0 -- Total:576, Zeros: 0.00%
# block4c_expand_bn_1/moving_mean:0 -- Total:576, Zeros: 0.00%
# block4c_expand_bn_1/moving_variance:0 -- Total:576, Zeros: 0.00%
# block4c_dwconv_1/depthwise_kernel:0 -- Total:5184, Zeros: 0.00%
# block4c_bn_1/gamma:0 -- Total:576, Zeros: 0.00%
# block4c_bn_1/beta:0 -- Total:576, Zeros: 0.00%
# block4c_bn_1/moving_mean:0 -- Total:576, Zeros: 0.00%
# block4c_bn_1/moving_variance:0 -- Total:576, Zeros: 0.00%
# block4c_se_reduce_1/kernel:0 -- Total:13824, Zeros: 79.63%
# block4c_se_reduce_1/bias:0 -- Total:24, Zeros: 0.00%
# block4c_se_expand_1/kernel:0 -- Total:13824, Zeros: 79.63%
# block4c_se_expand_1/bias:0 -- Total:576, Zeros: 0.00%
# block4c_project_conv_1/kernel:0 -- Total:55296, Zeros: 79.63%
# block4c_project_bn_1/gamma:0 -- Total:96, Zeros: 0.00%
# block4c_project_bn_1/beta:0 -- Total:96, Zeros: 0.00%
# block4c_project_bn_1/moving_mean:0 -- Total:96, Zeros: 0.00%
# block4c_project_bn_1/moving_variance:0 -- Total:96, Zeros: 0.00%
# block4d_expand_conv_1/kernel:0 -- Total:55296, Zeros: 79.63%
# block4d_expand_bn_1/gamma:0 -- Total:576, Zeros: 0.00%
# block4d_expand_bn_1/beta:0 -- Total:576, Zeros: 0.00%
# block4d_expand_bn_1/moving_mean:0 -- Total:576, Zeros: 0.00%
# block4d_expand_bn_1/moving_variance:0 -- Total:576, Zeros: 0.00%
# block4d_dwconv_1/depthwise_kernel:0 -- Total:5184, Zeros: 0.00%
# block4d_bn_1/gamma:0 -- Total:576, Zeros: 0.00%
# block4d_bn_1/beta:0 -- Total:576, Zeros: 0.00%
# block4d_bn_1/moving_mean:0 -- Total:576, Zeros: 0.00%
# block4d_bn_1/moving_variance:0 -- Total:576, Zeros: 0.00%
# block4d_se_reduce_1/kernel:0 -- Total:13824, Zeros: 79.63%
# block4d_se_reduce_1/bias:0 -- Total:24, Zeros: 0.00%
# block4d_se_expand_1/kernel:0 -- Total:13824, Zeros: 79.63%
# block4d_se_expand_1/bias:0 -- Total:576, Zeros: 0.00%
# block4d_project_conv_1/kernel:0 -- Total:55296, Zeros: 79.63%
# block4d_project_bn_1/gamma:0 -- Total:96, Zeros: 0.00%
# block4d_project_bn_1/beta:0 -- Total:96, Zeros: 0.00%
# block4d_project_bn_1/moving_mean:0 -- Total:96, Zeros: 0.00%
# block4d_project_bn_1/moving_variance:0 -- Total:96, Zeros: 0.00%
# block4e_expand_conv_1/kernel:0 -- Total:55296, Zeros: 79.63%
# block4e_expand_bn_1/gamma:0 -- Total:576, Zeros: 0.00%
# block4e_expand_bn_1/beta:0 -- Total:576, Zeros: 0.00%
# block4e_expand_bn_1/moving_mean:0 -- Total:576, Zeros: 0.00%
# block4e_expand_bn_1/moving_variance:0 -- Total:576, Zeros: 0.00%
# block4e_dwconv_1/depthwise_kernel:0 -- Total:5184, Zeros: 0.00%
# block4e_bn_1/gamma:0 -- Total:576, Zeros: 0.00%
# block4e_bn_1/beta:0 -- Total:576, Zeros: 0.00%
# block4e_bn_1/moving_mean:0 -- Total:576, Zeros: 0.00%
# block4e_bn_1/moving_variance:0 -- Total:576, Zeros: 0.00%
# block4e_se_reduce_1/kernel:0 -- Total:13824, Zeros: 79.63%
# block4e_se_reduce_1/bias:0 -- Total:24, Zeros: 0.00%
# block4e_se_expand_1/kernel:0 -- Total:13824, Zeros: 79.63%
# block4e_se_expand_1/bias:0 -- Total:576, Zeros: 0.00%
# block4e_project_conv_1/kernel:0 -- Total:55296, Zeros: 79.63%
# block4e_project_bn_1/gamma:0 -- Total:96, Zeros: 0.00%
# block4e_project_bn_1/beta:0 -- Total:96, Zeros: 0.00%
# block4e_project_bn_1/moving_mean:0 -- Total:96, Zeros: 0.00%
# block4e_project_bn_1/moving_variance:0 -- Total:96, Zeros: 0.00%
# block5a_expand_conv_1/kernel:0 -- Total:55296, Zeros: 79.63%
# block5a_expand_bn_1/gamma:0 -- Total:576, Zeros: 0.00%
# block5a_expand_bn_1/beta:0 -- Total:576, Zeros: 0.00%
# block5a_expand_bn_1/moving_mean:0 -- Total:576, Zeros: 0.00%
# block5a_expand_bn_1/moving_variance:0 -- Total:576, Zeros: 0.00%
# block5a_dwconv_1/depthwise_kernel:0 -- Total:14400, Zeros: 0.00%
# block5a_bn_1/gamma:0 -- Total:576, Zeros: 0.00%
# block5a_bn_1/beta:0 -- Total:576, Zeros: 0.00%
# block5a_bn_1/moving_mean:0 -- Total:576, Zeros: 0.00%
# block5a_bn_1/moving_variance:0 -- Total:576, Zeros: 0.00%
# block5a_se_reduce_1/kernel:0 -- Total:13824, Zeros: 79.63%
# block5a_se_reduce_1/bias:0 -- Total:24, Zeros: 0.00%
# block5a_se_expand_1/kernel:0 -- Total:13824, Zeros: 79.63%
# block5a_se_expand_1/bias:0 -- Total:576, Zeros: 0.00%
# block5a_project_conv_1/kernel:0 -- Total:78336, Zeros: 79.63%
# block5a_project_bn_1/gamma:0 -- Total:136, Zeros: 0.00%
# block5a_project_bn_1/beta:0 -- Total:136, Zeros: 0.00%
# block5a_project_bn_1/moving_mean:0 -- Total:136, Zeros: 0.00%
# block5a_project_bn_1/moving_variance:0 -- Total:136, Zeros: 0.00%
# block5b_expand_conv_1/kernel:0 -- Total:110976, Zeros: 79.63%
# block5b_expand_bn_1/gamma:0 -- Total:816, Zeros: 0.00%
# block5b_expand_bn_1/beta:0 -- Total:816, Zeros: 0.00%
# block5b_expand_bn_1/moving_mean:0 -- Total:816, Zeros: 0.00%
# block5b_expand_bn_1/moving_variance:0 -- Total:816, Zeros: 0.00%
# block5b_dwconv_1/depthwise_kernel:0 -- Total:20400, Zeros: 0.00%
# block5b_bn_1/gamma:0 -- Total:816, Zeros: 0.00%
# block5b_bn_1/beta:0 -- Total:816, Zeros: 0.00%
# block5b_bn_1/moving_mean:0 -- Total:816, Zeros: 0.00%
# block5b_bn_1/moving_variance:0 -- Total:816, Zeros: 0.00%
# block5b_se_reduce_1/kernel:0 -- Total:27744, Zeros: 79.63%
# block5b_se_reduce_1/bias:0 -- Total:34, Zeros: 0.00%
# block5b_se_expand_1/kernel:0 -- Total:27744, Zeros: 79.63%
# block5b_se_expand_1/bias:0 -- Total:816, Zeros: 0.00%
# block5b_project_conv_1/kernel:0 -- Total:110976, Zeros: 79.63%
# block5b_project_bn_1/gamma:0 -- Total:136, Zeros: 0.00%
# block5b_project_bn_1/beta:0 -- Total:136, Zeros: 0.00%
# block5b_project_bn_1/moving_mean:0 -- Total:136, Zeros: 0.00%
# block5b_project_bn_1/moving_variance:0 -- Total:136, Zeros: 0.00%
# block5c_expand_conv_1/kernel:0 -- Total:110976, Zeros: 79.63%
# block5c_expand_bn_1/gamma:0 -- Total:816, Zeros: 0.00%
# block5c_expand_bn_1/beta:0 -- Total:816, Zeros: 0.00%
# block5c_expand_bn_1/moving_mean:0 -- Total:816, Zeros: 0.00%
# block5c_expand_bn_1/moving_variance:0 -- Total:816, Zeros: 0.00%
# block5c_dwconv_1/depthwise_kernel:0 -- Total:20400, Zeros: 0.00%
# block5c_bn_1/gamma:0 -- Total:816, Zeros: 0.00%
# block5c_bn_1/beta:0 -- Total:816, Zeros: 0.00%
# block5c_bn_1/moving_mean:0 -- Total:816, Zeros: 0.00%
# block5c_bn_1/moving_variance:0 -- Total:816, Zeros: 0.00%
# block5c_se_reduce_1/kernel:0 -- Total:27744, Zeros: 79.63%
# block5c_se_reduce_1/bias:0 -- Total:34, Zeros: 0.00%
# block5c_se_expand_1/kernel:0 -- Total:27744, Zeros: 79.63%
# block5c_se_expand_1/bias:0 -- Total:816, Zeros: 0.00%
# block5c_project_conv_1/kernel:0 -- Total:110976, Zeros: 79.63%
# block5c_project_bn_1/gamma:0 -- Total:136, Zeros: 0.00%
# block5c_project_bn_1/beta:0 -- Total:136, Zeros: 0.00%
# block5c_project_bn_1/moving_mean:0 -- Total:136, Zeros: 0.00%
# block5c_project_bn_1/moving_variance:0 -- Total:136, Zeros: 0.00%
# block5d_expand_conv_1/kernel:0 -- Total:110976, Zeros: 79.63%
# block5d_expand_bn_1/gamma:0 -- Total:816, Zeros: 0.00%
# block5d_expand_bn_1/beta:0 -- Total:816, Zeros: 0.00%
# block5d_expand_bn_1/moving_mean:0 -- Total:816, Zeros: 0.00%
# block5d_expand_bn_1/moving_variance:0 -- Total:816, Zeros: 0.00%
# block5d_dwconv_1/depthwise_kernel:0 -- Total:20400, Zeros: 0.00%
# block5d_bn_1/gamma:0 -- Total:816, Zeros: 0.00%
# block5d_bn_1/beta:0 -- Total:816, Zeros: 0.00%
# block5d_bn_1/moving_mean:0 -- Total:816, Zeros: 0.00%
# block5d_bn_1/moving_variance:0 -- Total:816, Zeros: 0.00%
# block5d_se_reduce_1/kernel:0 -- Total:27744, Zeros: 79.63%
# block5d_se_reduce_1/bias:0 -- Total:34, Zeros: 0.00%
# block5d_se_expand_1/kernel:0 -- Total:27744, Zeros: 79.63%
# block5d_se_expand_1/bias:0 -- Total:816, Zeros: 0.00%
# block5d_project_conv_1/kernel:0 -- Total:110976, Zeros: 79.63%
# block5d_project_bn_1/gamma:0 -- Total:136, Zeros: 0.00%
# block5d_project_bn_1/beta:0 -- Total:136, Zeros: 0.00%
# block5d_project_bn_1/moving_mean:0 -- Total:136, Zeros: 0.00%
# block5d_project_bn_1/moving_variance:0 -- Total:136, Zeros: 0.00%
# block5e_expand_conv_1/kernel:0 -- Total:110976, Zeros: 79.63%
# block5e_expand_bn_1/gamma:0 -- Total:816, Zeros: 0.00%
# block5e_expand_bn_1/beta:0 -- Total:816, Zeros: 0.00%
# block5e_expand_bn_1/moving_mean:0 -- Total:816, Zeros: 0.00%
# block5e_expand_bn_1/moving_variance:0 -- Total:816, Zeros: 0.00%
# block5e_dwconv_1/depthwise_kernel:0 -- Total:20400, Zeros: 0.00%
# block5e_bn_1/gamma:0 -- Total:816, Zeros: 0.00%
# block5e_bn_1/beta:0 -- Total:816, Zeros: 0.00%
# block5e_bn_1/moving_mean:0 -- Total:816, Zeros: 0.00%
# block5e_bn_1/moving_variance:0 -- Total:816, Zeros: 0.00%
# block5e_se_reduce_1/kernel:0 -- Total:27744, Zeros: 79.63%
# block5e_se_reduce_1/bias:0 -- Total:34, Zeros: 0.00%
# block5e_se_expand_1/kernel:0 -- Total:27744, Zeros: 79.63%
# block5e_se_expand_1/bias:0 -- Total:816, Zeros: 0.00%
# block5e_project_conv_1/kernel:0 -- Total:110976, Zeros: 79.63%
# block5e_project_bn_1/gamma:0 -- Total:136, Zeros: 0.00%
# block5e_project_bn_1/beta:0 -- Total:136, Zeros: 0.00%
# block5e_project_bn_1/moving_mean:0 -- Total:136, Zeros: 0.00%
# block5e_project_bn_1/moving_variance:0 -- Total:136, Zeros: 0.00%
# block6a_expand_conv_1/kernel:0 -- Total:110976, Zeros: 79.63%
# block6a_expand_bn_1/gamma:0 -- Total:816, Zeros: 0.00%
# block6a_expand_bn_1/beta:0 -- Total:816, Zeros: 0.00%
# block6a_expand_bn_1/moving_mean:0 -- Total:816, Zeros: 0.00%
# block6a_expand_bn_1/moving_variance:0 -- Total:816, Zeros: 0.00%
# block6a_dwconv_1/depthwise_kernel:0 -- Total:20400, Zeros: 0.00%
# block6a_bn_1/gamma:0 -- Total:816, Zeros: 0.00%
# block6a_bn_1/beta:0 -- Total:816, Zeros: 0.00%
# block6a_bn_1/moving_mean:0 -- Total:816, Zeros: 0.00%
# block6a_bn_1/moving_variance:0 -- Total:816, Zeros: 0.00%
# block6a_se_reduce_1/kernel:0 -- Total:27744, Zeros: 79.63%
# block6a_se_reduce_1/bias:0 -- Total:34, Zeros: 0.00%
# block6a_se_expand_1/kernel:0 -- Total:27744, Zeros: 79.63%
# block6a_se_expand_1/bias:0 -- Total:816, Zeros: 0.00%
# block6a_project_conv_1/kernel:0 -- Total:189312, Zeros: 79.63%
# block6a_project_bn_1/gamma:0 -- Total:232, Zeros: 0.00%
# block6a_project_bn_1/beta:0 -- Total:232, Zeros: 0.00%
# block6a_project_bn_1/moving_mean:0 -- Total:232, Zeros: 0.00%
# block6a_project_bn_1/moving_variance:0 -- Total:232, Zeros: 0.00%
# block6b_expand_conv_1/kernel:0 -- Total:322944, Zeros: 79.63%
# block6b_expand_bn_1/gamma:0 -- Total:1392, Zeros: 0.00%
# block6b_expand_bn_1/beta:0 -- Total:1392, Zeros: 0.00%
# block6b_expand_bn_1/moving_mean:0 -- Total:1392, Zeros: 0.00%
# block6b_expand_bn_1/moving_variance:0 -- Total:1392, Zeros: 0.00%
# block6b_dwconv_1/depthwise_kernel:0 -- Total:34800, Zeros: 0.00%
# block6b_bn_1/gamma:0 -- Total:1392, Zeros: 0.00%
# block6b_bn_1/beta:0 -- Total:1392, Zeros: 0.00%
# block6b_bn_1/moving_mean:0 -- Total:1392, Zeros: 0.00%
# block6b_bn_1/moving_variance:0 -- Total:1392, Zeros: 0.00%
# block6b_se_reduce_1/kernel:0 -- Total:80736, Zeros: 79.63%
# block6b_se_reduce_1/bias:0 -- Total:58, Zeros: 0.00%
# block6b_se_expand_1/kernel:0 -- Total:80736, Zeros: 79.63%
# block6b_se_expand_1/bias:0 -- Total:1392, Zeros: 0.00%
# block6b_project_conv_1/kernel:0 -- Total:322944, Zeros: 79.63%
# block6b_project_bn_1/gamma:0 -- Total:232, Zeros: 0.00%
# block6b_project_bn_1/beta:0 -- Total:232, Zeros: 0.00%
# block6b_project_bn_1/moving_mean:0 -- Total:232, Zeros: 0.00%
# block6b_project_bn_1/moving_variance:0 -- Total:232, Zeros: 0.00%
# block6c_expand_conv_1/kernel:0 -- Total:322944, Zeros: 79.63%
# block6c_expand_bn_1/gamma:0 -- Total:1392, Zeros: 0.00%
# block6c_expand_bn_1/beta:0 -- Total:1392, Zeros: 0.00%
# block6c_expand_bn_1/moving_mean:0 -- Total:1392, Zeros: 0.00%
# block6c_expand_bn_1/moving_variance:0 -- Total:1392, Zeros: 0.00%
# block6c_dwconv_1/depthwise_kernel:0 -- Total:34800, Zeros: 0.00%
# block6c_bn_1/gamma:0 -- Total:1392, Zeros: 0.00%
# block6c_bn_1/beta:0 -- Total:1392, Zeros: 0.00%
# block6c_bn_1/moving_mean:0 -- Total:1392, Zeros: 0.00%
# block6c_bn_1/moving_variance:0 -- Total:1392, Zeros: 0.00%
# block6c_se_reduce_1/kernel:0 -- Total:80736, Zeros: 79.63%
# block6c_se_reduce_1/bias:0 -- Total:58, Zeros: 0.00%
# block6c_se_expand_1/kernel:0 -- Total:80736, Zeros: 79.63%
# block6c_se_expand_1/bias:0 -- Total:1392, Zeros: 0.00%
# block6c_project_conv_1/kernel:0 -- Total:322944, Zeros: 79.63%
# block6c_project_bn_1/gamma:0 -- Total:232, Zeros: 0.00%
# block6c_project_bn_1/beta:0 -- Total:232, Zeros: 0.00%
# block6c_project_bn_1/moving_mean:0 -- Total:232, Zeros: 0.00%
# block6c_project_bn_1/moving_variance:0 -- Total:232, Zeros: 0.00%
# block6d_expand_conv_1/kernel:0 -- Total:322944, Zeros: 79.63%
# block6d_expand_bn_1/gamma:0 -- Total:1392, Zeros: 0.00%
# block6d_expand_bn_1/beta:0 -- Total:1392, Zeros: 0.00%
# block6d_expand_bn_1/moving_mean:0 -- Total:1392, Zeros: 0.00%
# block6d_expand_bn_1/moving_variance:0 -- Total:1392, Zeros: 0.00%
# block6d_dwconv_1/depthwise_kernel:0 -- Total:34800, Zeros: 0.00%
# block6d_bn_1/gamma:0 -- Total:1392, Zeros: 0.00%
# block6d_bn_1/beta:0 -- Total:1392, Zeros: 0.00%
# block6d_bn_1/moving_mean:0 -- Total:1392, Zeros: 0.00%
# block6d_bn_1/moving_variance:0 -- Total:1392, Zeros: 0.00%
# block6d_se_reduce_1/kernel:0 -- Total:80736, Zeros: 79.63%
# block6d_se_reduce_1/bias:0 -- Total:58, Zeros: 0.00%
# block6d_se_expand_1/kernel:0 -- Total:80736, Zeros: 79.63%
# block6d_se_expand_1/bias:0 -- Total:1392, Zeros: 0.00%
# block6d_project_conv_1/kernel:0 -- Total:322944, Zeros: 79.63%
# block6d_project_bn_1/gamma:0 -- Total:232, Zeros: 0.00%
# block6d_project_bn_1/beta:0 -- Total:232, Zeros: 0.00%
# block6d_project_bn_1/moving_mean:0 -- Total:232, Zeros: 0.00%
# block6d_project_bn_1/moving_variance:0 -- Total:232, Zeros: 0.00%
# block6e_expand_conv_1/kernel:0 -- Total:322944, Zeros: 79.63%
# block6e_expand_bn_1/gamma:0 -- Total:1392, Zeros: 0.00%
# block6e_expand_bn_1/beta:0 -- Total:1392, Zeros: 0.00%
# block6e_expand_bn_1/moving_mean:0 -- Total:1392, Zeros: 0.00%
# block6e_expand_bn_1/moving_variance:0 -- Total:1392, Zeros: 0.00%
# block6e_dwconv_1/depthwise_kernel:0 -- Total:34800, Zeros: 0.00%
# block6e_bn_1/gamma:0 -- Total:1392, Zeros: 0.00%
# block6e_bn_1/beta:0 -- Total:1392, Zeros: 0.00%
# block6e_bn_1/moving_mean:0 -- Total:1392, Zeros: 0.00%
# block6e_bn_1/moving_variance:0 -- Total:1392, Zeros: 0.00%
# block6e_se_reduce_1/kernel:0 -- Total:80736, Zeros: 79.63%
# block6e_se_reduce_1/bias:0 -- Total:58, Zeros: 0.00%
# block6e_se_expand_1/kernel:0 -- Total:80736, Zeros: 79.63%
# block6e_se_expand_1/bias:0 -- Total:1392, Zeros: 0.00%
# block6e_project_conv_1/kernel:0 -- Total:322944, Zeros: 79.63%
# block6e_project_bn_1/gamma:0 -- Total:232, Zeros: 0.00%
# block6e_project_bn_1/beta:0 -- Total:232, Zeros: 0.00%
# block6e_project_bn_1/moving_mean:0 -- Total:232, Zeros: 0.00%
# block6e_project_bn_1/moving_variance:0 -- Total:232, Zeros: 0.00%
# block6f_expand_conv_1/kernel:0 -- Total:322944, Zeros: 79.63%
# block6f_expand_bn_1/gamma:0 -- Total:1392, Zeros: 0.00%
# block6f_expand_bn_1/beta:0 -- Total:1392, Zeros: 0.00%
# block6f_expand_bn_1/moving_mean:0 -- Total:1392, Zeros: 0.00%
# block6f_expand_bn_1/moving_variance:0 -- Total:1392, Zeros: 0.00%
# block6f_dwconv_1/depthwise_kernel:0 -- Total:34800, Zeros: 0.00%
# block6f_bn_1/gamma:0 -- Total:1392, Zeros: 0.00%
# block6f_bn_1/beta:0 -- Total:1392, Zeros: 0.00%
# block6f_bn_1/moving_mean:0 -- Total:1392, Zeros: 0.00%
# block6f_bn_1/moving_variance:0 -- Total:1392, Zeros: 0.00%
# block6f_se_reduce_1/kernel:0 -- Total:80736, Zeros: 79.63%
# block6f_se_reduce_1/bias:0 -- Total:58, Zeros: 0.00%
# block6f_se_expand_1/kernel:0 -- Total:80736, Zeros: 79.63%
# block6f_se_expand_1/bias:0 -- Total:1392, Zeros: 0.00%
# block6f_project_conv_1/kernel:0 -- Total:322944, Zeros: 79.63%
# block6f_project_bn_1/gamma:0 -- Total:232, Zeros: 0.00%
# block6f_project_bn_1/beta:0 -- Total:232, Zeros: 0.00%
# block6f_project_bn_1/moving_mean:0 -- Total:232, Zeros: 0.00%
# block6f_project_bn_1/moving_variance:0 -- Total:232, Zeros: 0.00%
# block7a_expand_conv_1/kernel:0 -- Total:322944, Zeros: 79.63%
# block7a_expand_bn_1/gamma:0 -- Total:1392, Zeros: 0.00%
# block7a_expand_bn_1/beta:0 -- Total:1392, Zeros: 0.00%
# block7a_expand_bn_1/moving_mean:0 -- Total:1392, Zeros: 0.00%
# block7a_expand_bn_1/moving_variance:0 -- Total:1392, Zeros: 0.00%
# block7a_dwconv_1/depthwise_kernel:0 -- Total:12528, Zeros: 0.00%
# block7a_bn_1/gamma:0 -- Total:1392, Zeros: 0.00%
# block7a_bn_1/beta:0 -- Total:1392, Zeros: 0.00%
# block7a_bn_1/moving_mean:0 -- Total:1392, Zeros: 0.00%
# block7a_bn_1/moving_variance:0 -- Total:1392, Zeros: 0.00%
# block7a_se_reduce_1/kernel:0 -- Total:80736, Zeros: 79.63%
# block7a_se_reduce_1/bias:0 -- Total:58, Zeros: 0.00%
# block7a_se_expand_1/kernel:0 -- Total:80736, Zeros: 79.63%
# block7a_se_expand_1/bias:0 -- Total:1392, Zeros: 0.00%
# block7a_project_conv_1/kernel:0 -- Total:534528, Zeros: 79.63%
# block7a_project_bn_1/gamma:0 -- Total:384, Zeros: 0.00%
# block7a_project_bn_1/beta:0 -- Total:384, Zeros: 0.00%
# block7a_project_bn_1/moving_mean:0 -- Total:384, Zeros: 0.00%
# block7a_project_bn_1/moving_variance:0 -- Total:384, Zeros: 0.00%
# block7b_expand_conv_1/kernel:0 -- Total:884736, Zeros: 79.63%
# block7b_expand_bn_1/gamma:0 -- Total:2304, Zeros: 0.00%
# block7b_expand_bn_1/beta:0 -- Total:2304, Zeros: 0.00%
# block7b_expand_bn_1/moving_mean:0 -- Total:2304, Zeros: 0.00%
# block7b_expand_bn_1/moving_variance:0 -- Total:2304, Zeros: 0.00%
# block7b_dwconv_1/depthwise_kernel:0 -- Total:20736, Zeros: 0.00%
# block7b_bn_1/gamma:0 -- Total:2304, Zeros: 0.00%
# block7b_bn_1/beta:0 -- Total:2304, Zeros: 0.00%
# block7b_bn_1/moving_mean:0 -- Total:2304, Zeros: 0.00%
# block7b_bn_1/moving_variance:0 -- Total:2304, Zeros: 0.00%
# block7b_se_reduce_1/kernel:0 -- Total:221184, Zeros: 79.63%
# block7b_se_reduce_1/bias:0 -- Total:96, Zeros: 0.00%
# block7b_se_expand_1/kernel:0 -- Total:221184, Zeros: 79.63%
# block7b_se_expand_1/bias:0 -- Total:2304, Zeros: 0.00%
# block7b_project_conv_1/kernel:0 -- Total:884736, Zeros: 79.63%
# block7b_project_bn_1/gamma:0 -- Total:384, Zeros: 0.00%
# block7b_project_bn_1/beta:0 -- Total:384, Zeros: 0.00%
# block7b_project_bn_1/moving_mean:0 -- Total:384, Zeros: 0.00%
# block7b_project_bn_1/moving_variance:0 -- Total:384, Zeros: 0.00%
# top_conv_1/kernel:0 -- Total:589824, Zeros: 79.63%
# top_bn_1/gamma:0 -- Total:1536, Zeros: 0.00%
# top_bn_1/beta:0 -- Total:1536, Zeros: 0.00%
# top_bn_1/moving_mean:0 -- Total:1536, Zeros: 0.00%
# top_bn_1/moving_variance:0 -- Total:1536, Zeros: 0.00%
# decoder_stage0a_conv_1/kernel:0 -- Total:5419008, Zeros: 79.63%
# decoder_stage0a_bn_1/gamma:0 -- Total:256, Zeros: 0.00%
# decoder_stage0a_bn_1/beta:0 -- Total:256, Zeros: 0.00%
# decoder_stage0a_bn_1/moving_mean:0 -- Total:256, Zeros: 0.00%
# decoder_stage0a_bn_1/moving_variance:0 -- Total:256, Zeros: 0.00%
# decoder_stage0b_conv_1/kernel:0 -- Total:589824, Zeros: 79.63%
# decoder_stage0b_bn_1/gamma:0 -- Total:256, Zeros: 0.00%
# decoder_stage0b_bn_1/beta:0 -- Total:256, Zeros: 0.00%
# decoder_stage0b_bn_1/moving_mean:0 -- Total:256, Zeros: 0.00%
# decoder_stage0b_bn_1/moving_variance:0 -- Total:256, Zeros: 0.00%
# decoder_stage1a_conv_1/kernel:0 -- Total:626688, Zeros: 79.63%
# decoder_stage1a_bn_1/gamma:0 -- Total:128, Zeros: 0.00%
# decoder_stage1a_bn_1/beta:0 -- Total:128, Zeros: 0.00%
# decoder_stage1a_bn_1/moving_mean:0 -- Total:128, Zeros: 0.00%
# decoder_stage1a_bn_1/moving_variance:0 -- Total:128, Zeros: 0.00%
# decoder_stage1b_conv_1/kernel:0 -- Total:147456, Zeros: 79.63%
# decoder_stage1b_bn_1/gamma:0 -- Total:128, Zeros: 0.00%
# decoder_stage1b_bn_1/beta:0 -- Total:128, Zeros: 0.00%
# decoder_stage1b_bn_1/moving_mean:0 -- Total:128, Zeros: 0.00%
# decoder_stage1b_bn_1/moving_variance:0 -- Total:128, Zeros: 0.00%
# decoder_stage2a_conv_1/kernel:0 -- Total:184320, Zeros: 79.63%
# decoder_stage2a_bn_1/gamma:0 -- Total:64, Zeros: 0.00%
# decoder_stage2a_bn_1/beta:0 -- Total:64, Zeros: 0.00%
# decoder_stage2a_bn_1/moving_mean:0 -- Total:64, Zeros: 0.00%
# decoder_stage2a_bn_1/moving_variance:0 -- Total:64, Zeros: 0.00%
# decoder_stage2b_conv_1/kernel:0 -- Total:36864, Zeros: 79.63%
# decoder_stage2b_bn_1/gamma:0 -- Total:64, Zeros: 0.00%
# decoder_stage2b_bn_1/beta:0 -- Total:64, Zeros: 0.00%
# decoder_stage2b_bn_1/moving_mean:0 -- Total:64, Zeros: 0.00%
# decoder_stage2b_bn_1/moving_variance:0 -- Total:64, Zeros: 0.00%
# decoder_stage3a_conv_1/kernel:0 -- Total:59904, Zeros: 79.63%
# decoder_stage3a_bn_1/gamma:0 -- Total:32, Zeros: 0.00%
# decoder_stage3a_bn_1/beta:0 -- Total:32, Zeros: 0.00%
# decoder_stage3a_bn_1/moving_mean:0 -- Total:32, Zeros: 0.00%
# decoder_stage3a_bn_1/moving_variance:0 -- Total:32, Zeros: 0.00%
# decoder_stage3b_conv_1/kernel:0 -- Total:9216, Zeros: 79.63%
# decoder_stage3b_bn_1/gamma:0 -- Total:32, Zeros: 0.00%
# decoder_stage3b_bn_1/beta:0 -- Total:32, Zeros: 0.00%
# decoder_stage3b_bn_1/moving_mean:0 -- Total:32, Zeros: 0.00%
# decoder_stage3b_bn_1/moving_variance:0 -- Total:32, Zeros: 0.00%
# decoder_stage4a_conv_1/kernel:0 -- Total:4608, Zeros: 79.62%
# decoder_stage4a_bn_1/gamma:0 -- Total:16, Zeros: 0.00%
# decoder_stage4a_bn_1/beta:0 -- Total:16, Zeros: 0.00%
# decoder_stage4a_bn_1/moving_mean:0 -- Total:16, Zeros: 0.00%
# decoder_stage4a_bn_1/moving_variance:0 -- Total:16, Zeros: 0.00%
# decoder_stage4b_conv_1/kernel:0 -- Total:2304, Zeros: 79.64%
# decoder_stage4b_bn_1/gamma:0 -- Total:16, Zeros: 0.00%
# decoder_stage4b_bn_1/beta:0 -- Total:16, Zeros: 0.00%
# decoder_stage4b_bn_1/moving_mean:0 -- Total:16, Zeros: 0.00%
# decoder_stage4b_bn_1/moving_variance:0 -- Total:16, Zeros: 0.00%
# final_conv_1/kernel:0 -- Total:144, Zeros: 79.86%
# final_conv_1/bias:0 -- Total:1, Zeros: 0.00%

# %%
final_model = compile_model(model_for_export)

# %%
import tempfile

def get_gzipped_model_size(model):
  # Returns size of gzipped model, in bytes.
  import os
  import zipfile

  _, keras_file = tempfile.mkstemp('.h5')
  model.save(keras_file, include_optimizer=False)

  _, zipped_file = tempfile.mkstemp('.zip')
  with zipfile.ZipFile(zipped_file, 'w', compression=zipfile.ZIP_DEFLATED) as f:
    f.write(keras_file)

  return os.path.getsize(zipped_file)

print("Size of gzipped pruned model without stripping: %.2f bytes" % (get_gzipped_model_size(model)))
print("Size of gzipped pruned model with stripping: %.2f bytes" % (get_gzipped_model_size(final_model)))

# %%
final_model.save('pruned_model_2.h5')

# %%
test_model = keras.models.load_model('pruned_model.h5', compile=False)

# %%
optim = keras.optimizers.Adam(LR)

# Segmentation models losses can be combined together by '+' and scaled by integer or float factor
dice_loss = sm.losses.DiceLoss()
focal_loss = sm.losses.BinaryFocalLoss() if N_CLASSES == 1 else sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

metrics = [sm.metrics.IOUScore(threshold=0.5), sm.metrics.FScore(threshold=0.5)]
test_model.compile(optim, total_loss, metrics)

# %%
print('[TRAINING THE MODEL]')

test_model.fit_generator(train_dataloader,
                    steps_per_epoch=STEPS_PER_EPOCH,
                    epochs=FIRST_TRAIN_EPOCHS,
                    validation_data=valid_dataloader,
                    callbacks=callbacks,
                    validation_steps=STEPS_VALID
                    )

print('[MODEL PRETRAINED]')

# %%
test_model.summary()

# %%
test_dataset = Dataset(
    test_images,
    test_annotations,
    classes=CLASSES,
    augmentation=get_validation_augmentation(),
    #preprocessing=get_preprocessing(preprocess_input),
)

test_dataloader = Dataloder(test_dataset, batch_size=1, shuffle=False)

ids = np.arange(len(test_dataset))


for i in ids:
    image, gt_mask = test_dataset[i]
    image = np.expand_dims(image, axis=0)
    image = np.expand_dims(image, axis=3)
    pr_mask = test_model.predict(image).round()
# img_kek = train_dataloader[0][0]
# pr_mask = model.predict(img_kek).round()
# plt.figure(figsize = (28,28))
# plt.imshow(img_kek[..., 0].squeeze(),cmap='gray')
# plt.show()
# print(np.max(img_kek))
#     cv2.imshow('mask', image[0][:][:])
#     cv2.waitKey(0)

    visualize(
        image=denormalize(image.squeeze()),
        gt_mask=gt_mask[..., 0].squeeze(),
        pr_mask=pr_mask[..., 0].squeeze(),
    )
